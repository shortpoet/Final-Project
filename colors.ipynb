# %%
import json
import pandas as pd
from pprint import pprint
import numpy as np

# %%
with open('drink_db.json', encoding="utf8") as myfile:
    data = json.load(myfile)
pprint(data['ingredients'])
# Out:
# {'-LBliqfhELe4RX3pTFr-': {'alcohol': True,
#                           'colour': '#e67c1c',
#                           'name': 'cognac',
#                           'type': 'brandy'},
#  '-LBljS77Ym0FY4LehVBJ': {'alcohol': True,
#                           'colour': '#71311b',
#                           'id': '-LBljS77Ym0FY4LehVBJ',
#                           'name': 'créme de cacao (brown)',
#                           'type': 'liqueur'},
#  '-LBlkhP9wKtuy1orVdxT': {'alcohol': False,
#                           'colour': '#ffffff',
#                           'name': 'fresh cream',
#                           'type': ''},
#  '-LBllYcWA01PTDbMSBvs': {'alcohol': True,
#                           'colour': '#e30004',
#                           'name': 'campari',
#                           'type': 'liqueur'},
#  '-LBlm8P2Hk-bWYymCbKL': {'alcohol': True,
#                           'colour': '#c53937',
#                           'id': '-LBlm8P2Hk-bWYymCbKL',
#                           'name': 'red vermouth',
#                           'type': 'vermouth'},
#  '-LBlmO7jPMnfUn7Yy3f-': {'alcohol': False,
#                           'colour': '#e3feff',
#                           'name': 'soda water',
#                           'type': ''},
#  '-LBlmefTdqCEevlK-0Uq': {'alcohol': True,
#                           'colour': '#efdc02',
#                           'name': 'calvados',
#                           'type': 'brandy'},
#  '-LBlmqnY9RFUdY45YcFK': {'alcohol': True,
#                           'colour': '#e7fff1',
#                           'name': 'gin',
#                           'type': 'gin'},
#  '-LBln6aI3hpnj0i_VWKZ': {'alcohol': True,
#                           'colour': '#fec72c',
#                           'name': 'apricot brandy',
#                           'type': 'brandy'},
#  '-LBlnWVeckyQ3PPLC0oi': {'alcohol': True,
#                           'colour': '#ffeae4',
#                           'name': 'maraschino',
#                           'type': 'liqueur'},
#  '-LBlnh1lXNV5k9i-x43i': {'alcohol': False,
#                           'colour': '#fff953',
#                           'name': 'lemon juice',
#                           'type': ''},
#  '-LBlo7wuoDpkRu04_n7D': {'alcohol': True,
#                           'colour': '#e9ffe8',
#                           'name': 'bacardi carta blanca',
#                           'type': 'rum'},
#  '-LBloMo60mxlDhsN2T7u': {'alcohol': False,
#                           'colour': '#deff62',
#                           'name': 'lime juice',
#                           'type': ''},
#  '-LBlohE8PfjT13gsjfnP': {'alcohol': False,
#                           'colour': '#e24138',
#                           'name': 'grenadine',
#                           'type': ''},
#  '-LBlotavscrdDTdWjtqk': {'alcohol': True,
#                           'colour': '#ffffff',
#                           'name': 'white rum',
#                           'type': 'rum'},
#  '-LBlpL1XTBpjk7imUQoX': {'alcohol': True,
#                           'colour': '#fefff3',
#                           'name': 'triple sec',
#                           'type': 'liqueur'},
#  '-LBlphvI5dEcJ9WLf3qa': {'alcohol': True,
#                           'colour': '#fafff7',
#                           'name': 'old tom gin',
#                           'type': 'gin'},
#  '-LBlq01CvGh9acY7zzn8': {'alcohol': False,
#                           'colour': '#fe9b06',
#                           'name': 'orange bitters',
#                           'type': ''},
#  '-LBlqHj0RvrgndFL-8Ik': {'alcohol': False,
#                           'colour': '#fc214f',
#                           'name': 'raspberry syrup',
#                           'type': ''},
#  '-LBlqSUWCECfJTx8aTG4': {'alcohol': False,
#                           'colour': '#fffeee',
#                           'name': 'egg white',
#                           'type': ''},
#  '-LBlqjWBSS8Pw__Wj8r1': {'alcohol': False,
#                           'colour': '#fffab1',
#                           'name': 'simple syrup',
#                           'type': ''},
#  '-LBlqxRyTSDbSwXywasY': {'alcohol': False,
#                           'colour': '#fedb04',
#                           'name': 'peach bitters',
#                           'type': ''},
#  '-LBlrSZXBJX-nDsBH2lF': {'alcohol': False,
#                           'colour': '#6ece4e',
#                           'name': 'mint leafs',
#                           'type': ''},
#  '-LBlrgcjKP2FiJHsovPk': {'alcohol': True,
#                           'colour': '#e9ffe8',
#                           'name': 'dry vermouth',
#                           'type': 'vermouth'},
#  '-LBlrtD1SzFKzBxHXKUe': {'alcohol': False,
#                           'colour': '#fdffe8',
#                           'name': 'sugar syrup',
#                           'type': ''},
#  '-LBlsBaAUaNgUdTCGXrS': {'alcohol': True,
#                           'colour': '#dc9f17',
#                           'name': 'rye whiskey',
#                           'type': 'whiskey'},
#  '-LBlt8sSn663yic7LVi4': {'alcohol': False,
#                           'colour': '#f86a0c',
#                           'name': 'angostura bitters',
#                           'type': ''},
#  '-LBltMdgN_sK2SC1HgMh': {'alcohol': False,
#                           'colour': '#ffbc00',
#                           'name': 'orange juice',
#                           'type': ''},
#  '-LBltb4i8ShWBiFkw_WU': {'alcohol': False,
#                           'colour': '#ffef83',
#                           'name': 'pineapple juice',
#                           'type': ''},
#  '-LBltyi_imj_WaMNhhuk': {'alcohol': True,
#                           'colour': '#c6ffa1',
#                           'id': '-LBltyi_imj_WaMNhhuk',
#                           'name': 'absinthe',
#                           'type': 'absinthe'},
#  '-LBluKKHS-9_8JT4Ksb9': {'alcohol': False,
#                           'colour': '#ffffff',
#                           'name': 'sugar cube',
#                           'type': ''},
#  '-LBluV-NUPQIbY9SKa_r': {'alcohol': False,
#                           'colour': '#d9fbff',
#                           'name': 'water',
#                           'type': ''},
#  '-LBluiwgtsO3I5-ges4P': {'alcohol': True,
#                           'colour': '#711802',
#                           'name': 'dark rum',
#                           'type': 'rum'},
#  '-LBlv2x97v5yNlHq4aVB': {'alcohol': True,
#                           'colour': '#efb026',
#                           'name': 'brandy',
#                           'type': 'brandy'},
#  '-LBlvXdlI0wI1N7WxiE2': {'alcohol': True,
#                           'colour': '#af0d00',
#                           'name': 'red port',
#                           'type': 'wine'},
#  '-LBlvf4TQRbv5AD0MuFi': {'alcohol': False,
#                           'colour': '#ffdd22',
#                           'name': 'egg yolk',
#                           'type': ''},
#  '-LBlw9dtpeo0m4topm3-': {'alcohol': True,
#                           'colour': '#ea951f',
#                           'name': 'drambuie',
#                           'type': 'liqueur'},
#  '-LBlwMlJ0z_m_fGrkYLF': {'alcohol': False,
#                           'colour': '#ffdf71',
#                           'name': 'orange flower water',
#                           'type': ''},
#  '-LBlwglejVHXJ8U89nXa': {'alcohol': False,
#                           'colour': '#cb810d',
#                           'name': 'vanilla extract',
#                           'type': ''},
#  '-LBlwr4jKkppvvXa2U58': {'alcohol': False,
#                           'colour': '#ff542b',
#                           'name': 'peychaud’s bitters',
#                           'type': ''},
#  '-LBlx5sVwv5bGTA1o_cD': {'alcohol': True,
#                           'colour': '#fbfff8',
#                           'name': 'vodka',
#                           'type': 'vodka'},
#  '-LBlxRLy3ebdKVWjlnD4': {'alcohol': True,
#                           'colour': '#deffe0',
#                           'id': '-LBlxRLy3ebdKVWjlnD4',
#                           'name': 'crème de menthe (white)',
#                           'type': 'liqueur'},
#  '-LBlxpPezAZyUXNg6FU2': {'alcohol': True,
#                           'colour': '#cc7123',
#                           'name': 'bourbon whiskey',
#                           'type': 'whiskey'},
#  '-LBly0bdcw7z45-iZDxc': {'alcohol': True,
#                           'colour': '#fffab9',
#                           'name': 'prosecco',
#                           'type': 'wine'},
#  '-LBlyE8-xQ947DvlpqWB': {'alcohol': False,
#                           'colour': '#fe843b',
#                           'name': 'peach puree',
#                           'type': ''},
#  '-LBlyPUhbwf1SM0UgCBN': {'alcohol': True,
#                           'colour': '#59290d',
#                           'name': 'coffee liqueur',
#                           'type': 'liqueur'},
#  '-LBlyYQ1bIKB3vnukMzr': {'alcohol': False,
#                           'colour': '#ff3b00',
#                           'name': 'tomato juice',
#                           'type': ''},
#  '-LBlyhQNeNaRaI0d4vNZ': {'alcohol': False,
#                           'colour': '#96291a',
#                           'name': 'worcestershire sauce',
#                           'type': ''},
#  '-LBlyrKnv7mGC4XFcGd-': {'alcohol': False,
#                           'colour': '#e63c00',
#                           'name': 'tabasco',
#                           'type': ''},
#  '-LBlz-1qZPqEKF7NYSP8': {'alcohol': False,
#                           'colour': '#d5a163',
#                           'name': 'celery salt',
#                           'type': ''},
#  '-LBlz9FGvtsTOS6S_GQL': {'alcohol': False,
#                           'colour': '#341410',
#                           'name': 'pepper',
#                           'type': ''},
#  '-LBlzhnRyDQ09E6AnnqI': {'alcohol': True,
#                           'colour': '#fff09c',
#                           'name': 'cachaça',
#                           'type': 'rum'},
#  '-LBlzvRbQlXx8Rbr6RRm': {'alcohol': False,
#                           'colour': '#32d930',
#                           'name': 'lime',
#                           'type': ''},
#  '-LBm-36uI_yaZzPA8eJY': {'alcohol': False,
#                           'colour': '#ffffff',
#                           'id': '-LBm-36uI_yaZzPA8eJY',
#                           'name': 'white sugar',
#                           'type': ''},
#  '-LBm-JbwEcFS2hw3s4t4': {'alcohol': True,
#                           'colour': '#fff7b0',
#                           'name': 'champagne',
#                           'type': 'champagne'},
#  '-LBm-Vua1Borvfk_jM2o': {'alcohol': True,
#                           'colour': '#fff9c5',
#                           'name': 'citron vodka',
#                           'type': 'vodka'},
#  '-LBm-i6w_YRrZTTqJNBo': {'alcohol': True,
#                           'colour': '#dd8527',
#                           'name': 'cointreau',
#                           'type': 'liqueur'},
#  '-LBm-pnc5IciyMJ1BW9T': {'alcohol': False,
#                           'colour': '#f1251f',
#                           'name': 'cranberry juice',
#                           'type': ''},
#  '-LBm0-bARNXhm8zC9Bxw': {'alcohol': False,
#                           'colour': '#622700',
#                           'name': 'cola',
#                           'type': ''},
#  '-LBm0BVTNo3J4463A7St': {'alcohol': True,
#                           'colour': '#d77924',
#                           'name': 'amaretto',
#                           'type': 'liqueur'},
#  '-LBm0OLSnWGjQVua7kWK': {'alcohol': True,
#                           'colour': '#e5a20d',
#                           'name': 'scotch',
#                           'type': 'whisky'},
#  '-LBm0jIUVfHnS_uh0sFp': {'alcohol': True,
#                           'colour': '#ffdf1a',
#                           'name': 'galliano',
#                           'type': 'liqueur'},
#  '-LBm0y-EiK5YchTvTEMD': {'alcohol': True,
#                           'colour': '#fdfbfb',
#                           'name': 'crème de cacao (white)',
#                           'type': 'liqueur'},
#  '-LBm1Fe-4qO6qBgifrps': {'alcohol': True,
#                           'colour': '#4db84a',
#                           'name': 'crème de menthe (green)',
#                           'type': 'liqueur'},
#  '-LBoQBfJI9EDNZyqOhK4': {'alcohol': False,
#                           'colour': '#fd7c5c',
#                           'name': 'grapefruit juice',
#                           'type': ''},
#  '-LBoQMZDZYhQB9EH4OZU': {'alcohol': False,
#                           'colour': '#fff0a2',
#                           'name': 'ginger ale',
#                           'type': ''},
#  '-LBoQWaUzfU0bLBpOnGL': {'alcohol': True,
#                           'colour': '#f6c62b',
#                           'name': 'irish whiskey',
#                           'type': 'whiskey'},
#  '-LBoQj3tJ3r0otn3j_7a': {'alcohol': False,
#                           'colour': '#2b0300',
#                           'name': 'hot coffee',
#                           'type': ''},
#  '-LBoQvBqDUqCPPvzY9e9': {'alcohol': True,
#                           'colour': '#fffeb8',
#                           'name': 'dry white wine',
#                           'type': 'wine'},
#  '-LBoR8NPrUFBmq7up1Kb': {'alcohol': True,
#                           'colour': '#91001f',
#                           'name': 'crème de cassis',
#                           'type': 'liqueur'},
#  '-LBoRKY8tCrZGIuyQjoc': {'alcohol': False,
#                           'colour': '#d49c3d',
#                           'name': 'brown sugar',
#                           'type': ''},
#  '-LBoRVusUFRdeJzj0Qyv': {'alcohol': True,
#                           'colour': '#fffeda',
#                           'name': 'tequila',
#                           'type': 'tequila'},
#  '-LBoRh5aXtW_tkNL71Hx': {'alcohol': False,
#                           'colour': '#f6fdf0',
#                           'name': 'gomme syrup',
#                           'type': ''},
#  '-LBoRseyk1AIMGq8vP3B': {'alcohol': True,
#                           'colour': '#ffd556',
#                           'name': 'orange curaćao',
#                           'type': 'liqueur'},
#  '-LBoS1KZWpJ79_MoIu8J': {'alcohol': False,
#                           'colour': '#fcfff6',
#                           'name': 'orgeat syrup',
#                           'type': ''},
#  '-LBoSAxdfk0x6ajDCyYy': {'alcohol': False,
#                           'colour': '#78e048',
#                           'name': 'mint sprigs',
#                           'type': ''},
#  '-LBoSHP-fa5f_3zmttfF': {'alcohol': True,
#                           'colour': '#fcffe7',
#                           'name': 'white cuban rum',
#                           'type': 'rum'},
#  '-LBoSSS8W5WAP1c7_12r': {'alcohol': True,
#                           'colour': '#e6bd40',
#                           'name': 'ginger beer',
#                           'type': 'beer'},
#  '-LBoSWaofGE097Tp471d': {'alcohol': False,
#                           'colour': '#ffffff',
#                           'name': 'powdered sugar',
#                           'type': ''},
#  '-LBoSc1HQN5bXkZgJ_qM': {'alcohol': False,
#                           'colour': '#fefffa',
#                           'name': 'coconut cream',
#                           'type': ''},
#  '-LBoSnar5BERyv4dkH82': {'alcohol': True,
#                           'colour': '#fff7ec',
#                           'name': 'kirsch',
#                           'type': 'brandy'},
#  '-LBoSw-kJm151UKOXSxE': {'alcohol': False,
#                           'colour': '#ff3b00',
#                           'name': 'strawberry syrup',
#                           'type': ''},
#  '-LBoTNWmYGiI0pTBhNcv': {'alcohol': True,
#                           'colour': '#ffecc6',
#                           'name': 'peach schnapps',
#                           'type': 'liqueur'},
#  '-LBoTW1uPrFCtZLoBFmf': {'alcohol': True,
#                           'colour': '#ff0038',
#                           'name': 'cherry liqueur',
#                           'type': 'liqueur'},
#  '-LBoToKenZGHhF5EgIqD': {'alcohol': True,
#                           'colour': '#fff1bd',
#                           'name': 'DOM Bénédictine',
#                           'type': 'liqueur'},
#  '-LBoTyReEeSeWSpkKJxr': {'alcohol': True,
#                           'colour': '#eaa600',
#                           'name': 'grand marnier',
#                           'type': 'liqueur'},
#  '-LBoUAwqAzikZJHOFXs3': {'alcohol': True,
#                           'colour': '#ffd48f',
#                           'id': '-LBoUAwqAzikZJHOFXs3',
#                           'name': 'baileys irish cream',
#                           'type': 'liqueur'},
#  '-LBoUPwGUK9alXSNjYss': {'alcohol': True,
#                           'colour': '#722d12',
#                           'name': 'kahlúa',
#                           'type': 'liqueur'},
#  '-LBoUYBIuEnOCqhXFpIg': {'alcohol': True,
#                           'colour': '#ffd900',
#                           'name': 'gold rum',
#                           'type': 'rum'},
#  '-LBoUqkkS4XuobHeIdKy': {'alcohol': True,
#                           'colour': '#44006a',
#                           'name': 'blackberry liqueur',
#                           'type': 'liqueur'},
#  '-LBoUxyX6tCpRfGYAikY': {'alcohol': False,
#                           'colour': '#b3c800',
#                           'name': 'olive juice',
#                           'type': ''},
#  '-LBoV7KImJ2U3rFheJ8I': {'alcohol': True,
#                           'colour': '#cf0034',
#                           'name': 'raspberry liqueur',
#                           'type': 'liqueur'},
#  '-LBoVRBVqtceQHHzesCF': {'alcohol': False,
#                           'colour': '#551f00',
#                           'name': 'espresso',
#                           'type': ''},
#  '-LBoVZbA8Ci7l_OpubiT': {'alcohol': True,
#                           'colour': '#dfffc6',
#                           'name': 'pisco',
#                           'type': 'brandy'},
#  '-LBoVyfXPGz8eq_L3Htd': {'alcohol': True,
#                           'colour': '#ff2455',
#                           'name': 'aperol',
#                           'type': 'liqueur'},
#  '-LBoW4_Fh3HD0zINzW0f': {'alcohol': False,
#                           'colour': '#ffde55',
#                           'name': 'agave nectar',
#                           'type': ''},
#  '-LBoWG5BfrJK788Wos-R': {'alcohol': True,
#                           'colour': '#ffeb82',
#                           'name': 'lillet blonde',
#                           'type': 'wine'},
#  '-LBoWMs1OIiaTI-5OZf0': {'alcohol': False,
#                           'colour': '#fcff00',
#                           'name': 'lemon twist',
#                           'type': ''},
#  '-LBoWRb3rTc6CV6dKXRc': {'alcohol': False,
#                           'colour': '#ffe200',
#                           'name': 'honey',
#                           'type': ''},
#  '-LBoWYhme38XZtPfdxbZ': {'alcohol': False,
#                           'colour': '#ffecb2',
#                           'name': 'onion',
#                           'type': ''},
#  '-LBoWhwyqcbyMWfT3RaN': {'alcohol': False,
#                           'colour': '#f11e00',
#                           'name': 'chili peppers',
#                           'type': ''},
#  '-LBoX7e8fyhKJc63KSAV': {'alcohol': False,
#                           'colour': '#ffffff',
#                           'name': 'salt',
#                           'type': ''}}

# %%
color=[]
name = []

# %%
data.keys()
# Out:
# dict_keys(['drinks', 'glasses', 'ingredients'])

# %%
for x in range(len(data['ingredients'])):
#     try:
        name.append(data['ingredients'])
#     except KeyError:
#         name.append('NA')

# %%
name
# Out:
# [{'-LBliqfhELe4RX3pTFr-': {'alcohol': True,
#    'colour': '#e67c1c',
#    'name': 'cognac',
#    'type': 'brandy'},
#   '-LBljS77Ym0FY4LehVBJ': {'alcohol': True,
#    'colour': '#71311b',
#    'id': '-LBljS77Ym0FY4LehVBJ',
#    'name': 'créme de cacao (brown)',
#    'type': 'liqueur'},
#   '-LBlkhP9wKtuy1orVdxT': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'fresh cream',
#    'type': ''},
#   '-LBllYcWA01PTDbMSBvs': {'alcohol': True,
#    'colour': '#e30004',
#    'name': 'campari',
#    'type': 'liqueur'},
#   '-LBlm8P2Hk-bWYymCbKL': {'alcohol': True,
#    'colour': '#c53937',
#    'id': '-LBlm8P2Hk-bWYymCbKL',
#    'name': 'red vermouth',
#    'type': 'vermouth'},
#   '-LBlmO7jPMnfUn7Yy3f-': {'alcohol': False,
#    'colour': '#e3feff',
#    'name': 'soda water',
#    'type': ''},
#   '-LBlmefTdqCEevlK-0Uq': {'alcohol': True,
#    'colour': '#efdc02',
#    'name': 'calvados',
#    'type': 'brandy'},
#   '-LBlmqnY9RFUdY45YcFK': {'alcohol': True,
#    'colour': '#e7fff1',
#    'name': 'gin',
#    'type': 'gin'},
#   '-LBln6aI3hpnj0i_VWKZ': {'alcohol': True,
#    'colour': '#fec72c',
#    'name': 'apricot brandy',
#    'type': 'brandy'},
#   '-LBlnWVeckyQ3PPLC0oi': {'alcohol': True,
#    'colour': '#ffeae4',
#    'name': 'maraschino',
#    'type': 'liqueur'},
#   '-LBlnh1lXNV5k9i-x43i': {'alcohol': False,
#    'colour': '#fff953',
#    'name': 'lemon juice',
#    'type': ''},
#   '-LBlo7wuoDpkRu04_n7D': {'alcohol': True,
#    'colour': '#e9ffe8',
#    'name': 'bacardi carta blanca',
#    'type': 'rum'},
#   '-LBloMo60mxlDhsN2T7u': {'alcohol': False,
#    'colour': '#deff62',
#    'name': 'lime juice',
#    'type': ''},
#   '-LBlohE8PfjT13gsjfnP': {'alcohol': False,
#    'colour': '#e24138',
#    'name': 'grenadine',
#    'type': ''},
#   '-LBlotavscrdDTdWjtqk': {'alcohol': True,
#    'colour': '#ffffff',
#    'name': 'white rum',
#    'type': 'rum'},
#   '-LBlpL1XTBpjk7imUQoX': {'alcohol': True,
#    'colour': '#fefff3',
#    'name': 'triple sec',
#    'type': 'liqueur'},
#   '-LBlphvI5dEcJ9WLf3qa': {'alcohol': True,
#    'colour': '#fafff7',
#    'name': 'old tom gin',
#    'type': 'gin'},
#   '-LBlq01CvGh9acY7zzn8': {'alcohol': False,
#    'colour': '#fe9b06',
#    'name': 'orange bitters',
#    'type': ''},
#   '-LBlqHj0RvrgndFL-8Ik': {'alcohol': False,
#    'colour': '#fc214f',
#    'name': 'raspberry syrup',
#    'type': ''},
#   '-LBlqSUWCECfJTx8aTG4': {'alcohol': False,
#    'colour': '#fffeee',
#    'name': 'egg white',
#    'type': ''},
#   '-LBlqjWBSS8Pw__Wj8r1': {'alcohol': False,
#    'colour': '#fffab1',
#    'name': 'simple syrup',
#    'type': ''},
#   '-LBlqxRyTSDbSwXywasY': {'alcohol': False,
#    'colour': '#fedb04',
#    'name': 'peach bitters',
#    'type': ''},
#   '-LBlrSZXBJX-nDsBH2lF': {'alcohol': False,
#    'colour': '#6ece4e',
#    'name': 'mint leafs',
#    'type': ''},
#   '-LBlrgcjKP2FiJHsovPk': {'alcohol': True,
#    'colour': '#e9ffe8',
#    'name': 'dry vermouth',
#    'type': 'vermouth'},
#   '-LBlrtD1SzFKzBxHXKUe': {'alcohol': False,
#    'colour': '#fdffe8',
#    'name': 'sugar syrup',
#    'type': ''},
#   '-LBlsBaAUaNgUdTCGXrS': {'alcohol': True,
#    'colour': '#dc9f17',
#    'name': 'rye whiskey',
#    'type': 'whiskey'},
#   '-LBlt8sSn663yic7LVi4': {'alcohol': False,
#    'colour': '#f86a0c',
#    'name': 'angostura bitters',
#    'type': ''},
#   '-LBltMdgN_sK2SC1HgMh': {'alcohol': False,
#    'colour': '#ffbc00',
#    'name': 'orange juice',
#    'type': ''},
#   '-LBltb4i8ShWBiFkw_WU': {'alcohol': False,
#    'colour': '#ffef83',
#    'name': 'pineapple juice',
#    'type': ''},
#   '-LBltyi_imj_WaMNhhuk': {'alcohol': True,
#    'colour': '#c6ffa1',
#    'id': '-LBltyi_imj_WaMNhhuk',
#    'name': 'absinthe',
#    'type': 'absinthe'},
#   '-LBluKKHS-9_8JT4Ksb9': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'sugar cube',
#    'type': ''},
#   '-LBluV-NUPQIbY9SKa_r': {'alcohol': False,
#    'colour': '#d9fbff',
#    'name': 'water',
#    'type': ''},
#   '-LBluiwgtsO3I5-ges4P': {'alcohol': True,
#    'colour': '#711802',
#    'name': 'dark rum',
#    'type': 'rum'},
#   '-LBlv2x97v5yNlHq4aVB': {'alcohol': True,
#    'colour': '#efb026',
#    'name': 'brandy',
#    'type': 'brandy'},
#   '-LBlvXdlI0wI1N7WxiE2': {'alcohol': True,
#    'colour': '#af0d00',
#    'name': 'red port',
#    'type': 'wine'},
#   '-LBlvf4TQRbv5AD0MuFi': {'alcohol': False,
#    'colour': '#ffdd22',
#    'name': 'egg yolk',
#    'type': ''},
#   '-LBlw9dtpeo0m4topm3-': {'alcohol': True,
#    'colour': '#ea951f',
#    'name': 'drambuie',
#    'type': 'liqueur'},
#   '-LBlwMlJ0z_m_fGrkYLF': {'alcohol': False,
#    'colour': '#ffdf71',
#    'name': 'orange flower water',
#    'type': ''},
#   '-LBlwglejVHXJ8U89nXa': {'alcohol': False,
#    'colour': '#cb810d',
#    'name': 'vanilla extract',
#    'type': ''},
#   '-LBlwr4jKkppvvXa2U58': {'alcohol': False,
#    'colour': '#ff542b',
#    'name': 'peychaud’s bitters',
#    'type': ''},
#   '-LBlx5sVwv5bGTA1o_cD': {'alcohol': True,
#    'colour': '#fbfff8',
#    'name': 'vodka',
#    'type': 'vodka'},
#   '-LBlxRLy3ebdKVWjlnD4': {'alcohol': True,
#    'colour': '#deffe0',
#    'id': '-LBlxRLy3ebdKVWjlnD4',
#    'name': 'crème de menthe (white)',
#    'type': 'liqueur'},
#   '-LBlxpPezAZyUXNg6FU2': {'alcohol': True,
#    'colour': '#cc7123',
#    'name': 'bourbon whiskey',
#    'type': 'whiskey'},
#   '-LBly0bdcw7z45-iZDxc': {'alcohol': True,
#    'colour': '#fffab9',
#    'name': 'prosecco',
#    'type': 'wine'},
#   '-LBlyE8-xQ947DvlpqWB': {'alcohol': False,
#    'colour': '#fe843b',
#    'name': 'peach puree',
#    'type': ''},
#   '-LBlyPUhbwf1SM0UgCBN': {'alcohol': True,
#    'colour': '#59290d',
#    'name': 'coffee liqueur',
#    'type': 'liqueur'},
#   '-LBlyYQ1bIKB3vnukMzr': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'tomato juice',
#    'type': ''},
#   '-LBlyhQNeNaRaI0d4vNZ': {'alcohol': False,
#    'colour': '#96291a',
#    'name': 'worcestershire sauce',
#    'type': ''},
#   '-LBlyrKnv7mGC4XFcGd-': {'alcohol': False,
#    'colour': '#e63c00',
#    'name': 'tabasco',
#    'type': ''},
#   '-LBlz-1qZPqEKF7NYSP8': {'alcohol': False,
#    'colour': '#d5a163',
#    'name': 'celery salt',
#    'type': ''},
#   '-LBlz9FGvtsTOS6S_GQL': {'alcohol': False,
#    'colour': '#341410',
#    'name': 'pepper',
#    'type': ''},
#   '-LBlzhnRyDQ09E6AnnqI': {'alcohol': True,
#    'colour': '#fff09c',
#    'name': 'cachaça',
#    'type': 'rum'},
#   '-LBlzvRbQlXx8Rbr6RRm': {'alcohol': False,
#    'colour': '#32d930',
#    'name': 'lime',
#    'type': ''},
#   '-LBm-36uI_yaZzPA8eJY': {'alcohol': False,
#    'colour': '#ffffff',
#    'id': '-LBm-36uI_yaZzPA8eJY',
#    'name': 'white sugar',
#    'type': ''},
#   '-LBm-JbwEcFS2hw3s4t4': {'alcohol': True,
#    'colour': '#fff7b0',
#    'name': 'champagne',
#    'type': 'champagne'},
#   '-LBm-Vua1Borvfk_jM2o': {'alcohol': True,
#    'colour': '#fff9c5',
#    'name': 'citron vodka',
#    'type': 'vodka'},
#   '-LBm-i6w_YRrZTTqJNBo': {'alcohol': True,
#    'colour': '#dd8527',
#    'name': 'cointreau',
#    'type': 'liqueur'},
#   '-LBm-pnc5IciyMJ1BW9T': {'alcohol': False,
#    'colour': '#f1251f',
#    'name': 'cranberry juice',
#    'type': ''},
#   '-LBm0-bARNXhm8zC9Bxw': {'alcohol': False,
#    'colour': '#622700',
#    'name': 'cola',
#    'type': ''},
#   '-LBm0BVTNo3J4463A7St': {'alcohol': True,
#    'colour': '#d77924',
#    'name': 'amaretto',
#    'type': 'liqueur'},
#   '-LBm0OLSnWGjQVua7kWK': {'alcohol': True,
#    'colour': '#e5a20d',
#    'name': 'scotch',
#    'type': 'whisky'},
#   '-LBm0jIUVfHnS_uh0sFp': {'alcohol': True,
#    'colour': '#ffdf1a',
#    'name': 'galliano',
#    'type': 'liqueur'},
#   '-LBm0y-EiK5YchTvTEMD': {'alcohol': True,
#    'colour': '#fdfbfb',
#    'name': 'crème de cacao (white)',
#    'type': 'liqueur'},
#   '-LBm1Fe-4qO6qBgifrps': {'alcohol': True,
#    'colour': '#4db84a',
#    'name': 'crème de menthe (green)',
#    'type': 'liqueur'},
#   '-LBoQBfJI9EDNZyqOhK4': {'alcohol': False,
#    'colour': '#fd7c5c',
#    'name': 'grapefruit juice',
#    'type': ''},
#   '-LBoQMZDZYhQB9EH4OZU': {'alcohol': False,
#    'colour': '#fff0a2',
#    'name': 'ginger ale',
#    'type': ''},
#   '-LBoQWaUzfU0bLBpOnGL': {'alcohol': True,
#    'colour': '#f6c62b',
#    'name': 'irish whiskey',
#    'type': 'whiskey'},
#   '-LBoQj3tJ3r0otn3j_7a': {'alcohol': False,
#    'colour': '#2b0300',
#    'name': 'hot coffee',
#    'type': ''},
#   '-LBoQvBqDUqCPPvzY9e9': {'alcohol': True,
#    'colour': '#fffeb8',
#    'name': 'dry white wine',
#    'type': 'wine'},
#   '-LBoR8NPrUFBmq7up1Kb': {'alcohol': True,
#    'colour': '#91001f',
#    'name': 'crème de cassis',
#    'type': 'liqueur'},
#   '-LBoRKY8tCrZGIuyQjoc': {'alcohol': False,
#    'colour': '#d49c3d',
#    'name': 'brown sugar',
#    'type': ''},
#   '-LBoRVusUFRdeJzj0Qyv': {'alcohol': True,
#    'colour': '#fffeda',
#    'name': 'tequila',
#    'type': 'tequila'},
#   '-LBoRh5aXtW_tkNL71Hx': {'alcohol': False,
#    'colour': '#f6fdf0',
#    'name': 'gomme syrup',
#    'type': ''},
#   '-LBoRseyk1AIMGq8vP3B': {'alcohol': True,
#    'colour': '#ffd556',
#    'name': 'orange curaćao',
#    'type': 'liqueur'},
#   '-LBoS1KZWpJ79_MoIu8J': {'alcohol': False,
#    'colour': '#fcfff6',
#    'name': 'orgeat syrup',
#    'type': ''},
#   '-LBoSAxdfk0x6ajDCyYy': {'alcohol': False,
#    'colour': '#78e048',
#    'name': 'mint sprigs',
#    'type': ''},
#   '-LBoSHP-fa5f_3zmttfF': {'alcohol': True,
#    'colour': '#fcffe7',
#    'name': 'white cuban rum',
#    'type': 'rum'},
#   '-LBoSSS8W5WAP1c7_12r': {'alcohol': True,
#    'colour': '#e6bd40',
#    'name': 'ginger beer',
#    'type': 'beer'},
#   '-LBoSWaofGE097Tp471d': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'powdered sugar',
#    'type': ''},
#   '-LBoSc1HQN5bXkZgJ_qM': {'alcohol': False,
#    'colour': '#fefffa',
#    'name': 'coconut cream',
#    'type': ''},
#   '-LBoSnar5BERyv4dkH82': {'alcohol': True,
#    'colour': '#fff7ec',
#    'name': 'kirsch',
#    'type': 'brandy'},
#   '-LBoSw-kJm151UKOXSxE': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'strawberry syrup',
#    'type': ''},
#   '-LBoTNWmYGiI0pTBhNcv': {'alcohol': True,
#    'colour': '#ffecc6',
#    'name': 'peach schnapps',
#    'type': 'liqueur'},
#   '-LBoTW1uPrFCtZLoBFmf': {'alcohol': True,
#    'colour': '#ff0038',
#    'name': 'cherry liqueur',
#    'type': 'liqueur'},
#   '-LBoToKenZGHhF5EgIqD': {'alcohol': True,
#    'colour': '#fff1bd',
#    'name': 'DOM Bénédictine',
#    'type': 'liqueur'},
#   '-LBoTyReEeSeWSpkKJxr': {'alcohol': True,
#    'colour': '#eaa600',
#    'name': 'grand marnier',
#    'type': 'liqueur'},
#   '-LBoUAwqAzikZJHOFXs3': {'alcohol': True,
#    'colour': '#ffd48f',
#    'id': '-LBoUAwqAzikZJHOFXs3',
#    'name': 'baileys irish cream',
#    'type': 'liqueur'},
#   '-LBoUPwGUK9alXSNjYss': {'alcohol': True,
#    'colour': '#722d12',
#    'name': 'kahlúa',
#    'type': 'liqueur'},
#   '-LBoUYBIuEnOCqhXFpIg': {'alcohol': True,
#    'colour': '#ffd900',
#    'name': 'gold rum',
#    'type': 'rum'},
#   '-LBoUqkkS4XuobHeIdKy': {'alcohol': True,
#    'colour': '#44006a',
#    'name': 'blackberry liqueur',
#    'type': 'liqueur'},
#   '-LBoUxyX6tCpRfGYAikY': {'alcohol': False,
#    'colour': '#b3c800',
#    'name': 'olive juice',
#    'type': ''},
#   '-LBoV7KImJ2U3rFheJ8I': {'alcohol': True,
#    'colour': '#cf0034',
#    'name': 'raspberry liqueur',
#    'type': 'liqueur'},
#   '-LBoVRBVqtceQHHzesCF': {'alcohol': False,
#    'colour': '#551f00',
#    'name': 'espresso',
#    'type': ''},
#   '-LBoVZbA8Ci7l_OpubiT': {'alcohol': True,
#    'colour': '#dfffc6',
#    'name': 'pisco',
#    'type': 'brandy'},
#   '-LBoVyfXPGz8eq_L3Htd': {'alcohol': True,
#    'colour': '#ff2455',
#    'name': 'aperol',
#    'type': 'liqueur'},
#   '-LBoW4_Fh3HD0zINzW0f': {'alcohol': False,
#    'colour': '#ffde55',
#    'name': 'agave nectar',
#    'type': ''},
#   '-LBoWG5BfrJK788Wos-R': {'alcohol': True,
#    'colour': '#ffeb82',
#    'name': 'lillet blonde',
#    'type': 'wine'},
#   '-LBoWMs1OIiaTI-5OZf0': {'alcohol': False,
#    'colour': '#fcff00',
#    'name': 'lemon twist',
#    'type': ''},
#   '-LBoWRb3rTc6CV6dKXRc': {'alcohol': False,
#    'colour': '#ffe200',
#    'name': 'honey',
#    'type': ''},
#   '-LBoWYhme38XZtPfdxbZ': {'alcohol': False,
#    'colour': '#ffecb2',
#    'name': 'onion',
#    'type': ''},
#   '-LBoWhwyqcbyMWfT3RaN': {'alcohol': False,
#    'colour': '#f11e00',
#    'name': 'chili peppers',
#    'type': ''},
#   '-LBoX7e8fyhKJc63KSAV': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'salt',
#    'type': ''}},
#  {'-LBliqfhELe4RX3pTFr-': {'alcohol': True,
#    'colour': '#e67c1c',
#    'name': 'cognac',
#    'type': 'brandy'},
#   '-LBljS77Ym0FY4LehVBJ': {'alcohol': True,
#    'colour': '#71311b',
#    'id': '-LBljS77Ym0FY4LehVBJ',
#    'name': 'créme de cacao (brown)',
#    'type': 'liqueur'},
#   '-LBlkhP9wKtuy1orVdxT': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'fresh cream',
#    'type': ''},
#   '-LBllYcWA01PTDbMSBvs': {'alcohol': True,
#    'colour': '#e30004',
#    'name': 'campari',
#    'type': 'liqueur'},
#   '-LBlm8P2Hk-bWYymCbKL': {'alcohol': True,
#    'colour': '#c53937',
#    'id': '-LBlm8P2Hk-bWYymCbKL',
#    'name': 'red vermouth',
#    'type': 'vermouth'},
#   '-LBlmO7jPMnfUn7Yy3f-': {'alcohol': False,
#    'colour': '#e3feff',
#    'name': 'soda water',
#    'type': ''},
#   '-LBlmefTdqCEevlK-0Uq': {'alcohol': True,
#    'colour': '#efdc02',
#    'name': 'calvados',
#    'type': 'brandy'},
#   '-LBlmqnY9RFUdY45YcFK': {'alcohol': True,
#    'colour': '#e7fff1',
#    'name': 'gin',
#    'type': 'gin'},
#   '-LBln6aI3hpnj0i_VWKZ': {'alcohol': True,
#    'colour': '#fec72c',
#    'name': 'apricot brandy',
#    'type': 'brandy'},
#   '-LBlnWVeckyQ3PPLC0oi': {'alcohol': True,
#    'colour': '#ffeae4',
#    'name': 'maraschino',
#    'type': 'liqueur'},
#   '-LBlnh1lXNV5k9i-x43i': {'alcohol': False,
#    'colour': '#fff953',
#    'name': 'lemon juice',
#    'type': ''},
#   '-LBlo7wuoDpkRu04_n7D': {'alcohol': True,
#    'colour': '#e9ffe8',
#    'name': 'bacardi carta blanca',
#    'type': 'rum'},
#   '-LBloMo60mxlDhsN2T7u': {'alcohol': False,
#    'colour': '#deff62',
#    'name': 'lime juice',
#    'type': ''},
#   '-LBlohE8PfjT13gsjfnP': {'alcohol': False,
#    'colour': '#e24138',
#    'name': 'grenadine',
#    'type': ''},
#   '-LBlotavscrdDTdWjtqk': {'alcohol': True,
#    'colour': '#ffffff',
#    'name': 'white rum',
#    'type': 'rum'},
#   '-LBlpL1XTBpjk7imUQoX': {'alcohol': True,
#    'colour': '#fefff3',
#    'name': 'triple sec',
#    'type': 'liqueur'},
#   '-LBlphvI5dEcJ9WLf3qa': {'alcohol': True,
#    'colour': '#fafff7',
#    'name': 'old tom gin',
#    'type': 'gin'},
#   '-LBlq01CvGh9acY7zzn8': {'alcohol': False,
#    'colour': '#fe9b06',
#    'name': 'orange bitters',
#    'type': ''},
#   '-LBlqHj0RvrgndFL-8Ik': {'alcohol': False,
#    'colour': '#fc214f',
#    'name': 'raspberry syrup',
#    'type': ''},
#   '-LBlqSUWCECfJTx8aTG4': {'alcohol': False,
#    'colour': '#fffeee',
#    'name': 'egg white',
#    'type': ''},
#   '-LBlqjWBSS8Pw__Wj8r1': {'alcohol': False,
#    'colour': '#fffab1',
#    'name': 'simple syrup',
#    'type': ''},
#   '-LBlqxRyTSDbSwXywasY': {'alcohol': False,
#    'colour': '#fedb04',
#    'name': 'peach bitters',
#    'type': ''},
#   '-LBlrSZXBJX-nDsBH2lF': {'alcohol': False,
#    'colour': '#6ece4e',
#    'name': 'mint leafs',
#    'type': ''},
#   '-LBlrgcjKP2FiJHsovPk': {'alcohol': True,
#    'colour': '#e9ffe8',
#    'name': 'dry vermouth',
#    'type': 'vermouth'},
#   '-LBlrtD1SzFKzBxHXKUe': {'alcohol': False,
#    'colour': '#fdffe8',
#    'name': 'sugar syrup',
#    'type': ''},
#   '-LBlsBaAUaNgUdTCGXrS': {'alcohol': True,
#    'colour': '#dc9f17',
#    'name': 'rye whiskey',
#    'type': 'whiskey'},
#   '-LBlt8sSn663yic7LVi4': {'alcohol': False,
#    'colour': '#f86a0c',
#    'name': 'angostura bitters',
#    'type': ''},
#   '-LBltMdgN_sK2SC1HgMh': {'alcohol': False,
#    'colour': '#ffbc00',
#    'name': 'orange juice',
#    'type': ''},
#   '-LBltb4i8ShWBiFkw_WU': {'alcohol': False,
#    'colour': '#ffef83',
#    'name': 'pineapple juice',
#    'type': ''},
#   '-LBltyi_imj_WaMNhhuk': {'alcohol': True,
#    'colour': '#c6ffa1',
#    'id': '-LBltyi_imj_WaMNhhuk',
#    'name': 'absinthe',
#    'type': 'absinthe'},
#   '-LBluKKHS-9_8JT4Ksb9': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'sugar cube',
#    'type': ''},
#   '-LBluV-NUPQIbY9SKa_r': {'alcohol': False,
#    'colour': '#d9fbff',
#    'name': 'water',
#    'type': ''},
#   '-LBluiwgtsO3I5-ges4P': {'alcohol': True,
#    'colour': '#711802',
#    'name': 'dark rum',
#    'type': 'rum'},
#   '-LBlv2x97v5yNlHq4aVB': {'alcohol': True,
#    'colour': '#efb026',
#    'name': 'brandy',
#    'type': 'brandy'},
#   '-LBlvXdlI0wI1N7WxiE2': {'alcohol': True,
#    'colour': '#af0d00',
#    'name': 'red port',
#    'type': 'wine'},
#   '-LBlvf4TQRbv5AD0MuFi': {'alcohol': False,
#    'colour': '#ffdd22',
#    'name': 'egg yolk',
#    'type': ''},
#   '-LBlw9dtpeo0m4topm3-': {'alcohol': True,
#    'colour': '#ea951f',
#    'name': 'drambuie',
#    'type': 'liqueur'},
#   '-LBlwMlJ0z_m_fGrkYLF': {'alcohol': False,
#    'colour': '#ffdf71',
#    'name': 'orange flower water',
#    'type': ''},
#   '-LBlwglejVHXJ8U89nXa': {'alcohol': False,
#    'colour': '#cb810d',
#    'name': 'vanilla extract',
#    'type': ''},
#   '-LBlwr4jKkppvvXa2U58': {'alcohol': False,
#    'colour': '#ff542b',
#    'name': 'peychaud’s bitters',
#    'type': ''},
#   '-LBlx5sVwv5bGTA1o_cD': {'alcohol': True,
#    'colour': '#fbfff8',
#    'name': 'vodka',
#    'type': 'vodka'},
#   '-LBlxRLy3ebdKVWjlnD4': {'alcohol': True,
#    'colour': '#deffe0',
#    'id': '-LBlxRLy3ebdKVWjlnD4',
#    'name': 'crème de menthe (white)',
#    'type': 'liqueur'},
#   '-LBlxpPezAZyUXNg6FU2': {'alcohol': True,
#    'colour': '#cc7123',
#    'name': 'bourbon whiskey',
#    'type': 'whiskey'},
#   '-LBly0bdcw7z45-iZDxc': {'alcohol': True,
#    'colour': '#fffab9',
#    'name': 'prosecco',
#    'type': 'wine'},
#   '-LBlyE8-xQ947DvlpqWB': {'alcohol': False,
#    'colour': '#fe843b',
#    'name': 'peach puree',
#    'type': ''},
#   '-LBlyPUhbwf1SM0UgCBN': {'alcohol': True,
#    'colour': '#59290d',
#    'name': 'coffee liqueur',
#    'type': 'liqueur'},
#   '-LBlyYQ1bIKB3vnukMzr': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'tomato juice',
#    'type': ''},
#   '-LBlyhQNeNaRaI0d4vNZ': {'alcohol': False,
#    'colour': '#96291a',
#    'name': 'worcestershire sauce',
#    'type': ''},
#   '-LBlyrKnv7mGC4XFcGd-': {'alcohol': False,
#    'colour': '#e63c00',
#    'name': 'tabasco',
#    'type': ''},
#   '-LBlz-1qZPqEKF7NYSP8': {'alcohol': False,
#    'colour': '#d5a163',
#    'name': 'celery salt',
#    'type': ''},
#   '-LBlz9FGvtsTOS6S_GQL': {'alcohol': False,
#    'colour': '#341410',
#    'name': 'pepper',
#    'type': ''},
#   '-LBlzhnRyDQ09E6AnnqI': {'alcohol': True,
#    'colour': '#fff09c',
#    'name': 'cachaça',
#    'type': 'rum'},
#   '-LBlzvRbQlXx8Rbr6RRm': {'alcohol': False,
#    'colour': '#32d930',
#    'name': 'lime',
#    'type': ''},
#   '-LBm-36uI_yaZzPA8eJY': {'alcohol': False,
#    'colour': '#ffffff',
#    'id': '-LBm-36uI_yaZzPA8eJY',
#    'name': 'white sugar',
#    'type': ''},
#   '-LBm-JbwEcFS2hw3s4t4': {'alcohol': True,
#    'colour': '#fff7b0',
#    'name': 'champagne',
#    'type': 'champagne'},
#   '-LBm-Vua1Borvfk_jM2o': {'alcohol': True,
#    'colour': '#fff9c5',
#    'name': 'citron vodka',
#    'type': 'vodka'},
#   '-LBm-i6w_YRrZTTqJNBo': {'alcohol': True,
#    'colour': '#dd8527',
#    'name': 'cointreau',
#    'type': 'liqueur'},
#   '-LBm-pnc5IciyMJ1BW9T': {'alcohol': False,
#    'colour': '#f1251f',
#    'name': 'cranberry juice',
#    'type': ''},
#   '-LBm0-bARNXhm8zC9Bxw': {'alcohol': False,
#    'colour': '#622700',
#    'name': 'cola',
#    'type': ''},
#   '-LBm0BVTNo3J4463A7St': {'alcohol': True,
#    'colour': '#d77924',
#    'name': 'amaretto',
#    'type': 'liqueur'},
#   '-LBm0OLSnWGjQVua7kWK': {'alcohol': True,
#    'colour': '#e5a20d',
#    'name': 'scotch',
#    'type': 'whisky'},
#   '-LBm0jIUVfHnS_uh0sFp': {'alcohol': True,
#    'colour': '#ffdf1a',
#    'name': 'galliano',
#    'type': 'liqueur'},
#   '-LBm0y-EiK5YchTvTEMD': {'alcohol': True,
#    'colour': '#fdfbfb',
#    'name': 'crème de cacao (white)',
#    'type': 'liqueur'},
#   '-LBm1Fe-4qO6qBgifrps': {'alcohol': True,
#    'colour': '#4db84a',
#    'name': 'crème de menthe (green)',
#    'type': 'liqueur'},
#   '-LBoQBfJI9EDNZyqOhK4': {'alcohol': False,
#    'colour': '#fd7c5c',
#    'name': 'grapefruit juice',
#    'type': ''},
#   '-LBoQMZDZYhQB9EH4OZU': {'alcohol': False,
#    'colour': '#fff0a2',
#    'name': 'ginger ale',
#    'type': ''},
#   '-LBoQWaUzfU0bLBpOnGL': {'alcohol': True,
#    'colour': '#f6c62b',
#    'name': 'irish whiskey',
#    'type': 'whiskey'},
#   '-LBoQj3tJ3r0otn3j_7a': {'alcohol': False,
#    'colour': '#2b0300',
#    'name': 'hot coffee',
#    'type': ''},
#   '-LBoQvBqDUqCPPvzY9e9': {'alcohol': True,
#    'colour': '#fffeb8',
#    'name': 'dry white wine',
#    'type': 'wine'},
#   '-LBoR8NPrUFBmq7up1Kb': {'alcohol': True,
#    'colour': '#91001f',
#    'name': 'crème de cassis',
#    'type': 'liqueur'},
#   '-LBoRKY8tCrZGIuyQjoc': {'alcohol': False,
#    'colour': '#d49c3d',
#    'name': 'brown sugar',
#    'type': ''},
#   '-LBoRVusUFRdeJzj0Qyv': {'alcohol': True,
#    'colour': '#fffeda',
#    'name': 'tequila',
#    'type': 'tequila'},
#   '-LBoRh5aXtW_tkNL71Hx': {'alcohol': False,
#    'colour': '#f6fdf0',
#    'name': 'gomme syrup',
#    'type': ''},
#   '-LBoRseyk1AIMGq8vP3B': {'alcohol': True,
#    'colour': '#ffd556',
#    'name': 'orange curaćao',
#    'type': 'liqueur'},
#   '-LBoS1KZWpJ79_MoIu8J': {'alcohol': False,
#    'colour': '#fcfff6',
#    'name': 'orgeat syrup',
#    'type': ''},
#   '-LBoSAxdfk0x6ajDCyYy': {'alcohol': False,
#    'colour': '#78e048',
#    'name': 'mint sprigs',
#    'type': ''},
#   '-LBoSHP-fa5f_3zmttfF': {'alcohol': True,
#    'colour': '#fcffe7',
#    'name': 'white cuban rum',
#    'type': 'rum'},
#   '-LBoSSS8W5WAP1c7_12r': {'alcohol': True,
#    'colour': '#e6bd40',
#    'name': 'ginger beer',
#    'type': 'beer'},
#   '-LBoSWaofGE097Tp471d': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'powdered sugar',
#    'type': ''},
#   '-LBoSc1HQN5bXkZgJ_qM': {'alcohol': False,
#    'colour': '#fefffa',
#    'name': 'coconut cream',
#    'type': ''},
#   '-LBoSnar5BERyv4dkH82': {'alcohol': True,
#    'colour': '#fff7ec',
#    'name': 'kirsch',
#    'type': 'brandy'},
#   '-LBoSw-kJm151UKOXSxE': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'strawberry syrup',
#    'type': ''},
#   '-LBoTNWmYGiI0pTBhNcv': {'alcohol': True,
#    'colour': '#ffecc6',
#    'name': 'peach schnapps',
#    'type': 'liqueur'},
#   '-LBoTW1uPrFCtZLoBFmf': {'alcohol': True,
#    'colour': '#ff0038',
#    'name': 'cherry liqueur',
#    'type': 'liqueur'},
#   '-LBoToKenZGHhF5EgIqD': {'alcohol': True,
#    'colour': '#fff1bd',
#    'name': 'DOM Bénédictine',
#    'type': 'liqueur'},
#   '-LBoTyReEeSeWSpkKJxr': {'alcohol': True,
#    'colour': '#eaa600',
#    'name': 'grand marnier',
#    'type': 'liqueur'},
#   '-LBoUAwqAzikZJHOFXs3': {'alcohol': True,
#    'colour': '#ffd48f',
#    'id': '-LBoUAwqAzikZJHOFXs3',
#    'name': 'baileys irish cream',
#    'type': 'liqueur'},
#   '-LBoUPwGUK9alXSNjYss': {'alcohol': True,
#    'colour': '#722d12',
#    'name': 'kahlúa',
#    'type': 'liqueur'},
#   '-LBoUYBIuEnOCqhXFpIg': {'alcohol': True,
#    'colour': '#ffd900',
#    'name': 'gold rum',
#    'type': 'rum'},
#   '-LBoUqkkS4XuobHeIdKy': {'alcohol': True,
#    'colour': '#44006a',
#    'name': 'blackberry liqueur',
#    'type': 'liqueur'},
#   '-LBoUxyX6tCpRfGYAikY': {'alcohol': False,
#    'colour': '#b3c800',
#    'name': 'olive juice',
#    'type': ''},
#   '-LBoV7KImJ2U3rFheJ8I': {'alcohol': True,
#    'colour': '#cf0034',
#    'name': 'raspberry liqueur',
#    'type': 'liqueur'},
#   '-LBoVRBVqtceQHHzesCF': {'alcohol': False,
#    'colour': '#551f00',
#    'name': 'espresso',
#    'type': ''},
#   '-LBoVZbA8Ci7l_OpubiT': {'alcohol': True,
#    'colour': '#dfffc6',
#    'name': 'pisco',
#    'type': 'brandy'},
#   '-LBoVyfXPGz8eq_L3Htd': {'alcohol': True,
#    'colour': '#ff2455',
#    'name': 'aperol',
#    'type': 'liqueur'},
#   '-LBoW4_Fh3HD0zINzW0f': {'alcohol': False,
#    'colour': '#ffde55',
#    'name': 'agave nectar',
#    'type': ''},
#   '-LBoWG5BfrJK788Wos-R': {'alcohol': True,
#    'colour': '#ffeb82',
#    'name': 'lillet blonde',
#    'type': 'wine'},
#   '-LBoWMs1OIiaTI-5OZf0': {'alcohol': False,
#    'colour': '#fcff00',
#    'name': 'lemon twist',
#    'type': ''},
#   '-LBoWRb3rTc6CV6dKXRc': {'alcohol': False,
#    'colour': '#ffe200',
#    'name': 'honey',
#    'type': ''},
#   '-LBoWYhme38XZtPfdxbZ': {'alcohol': False,
#    'colour': '#ffecb2',
#    'name': 'onion',
#    'type': ''},
#   '-LBoWhwyqcbyMWfT3RaN': {'alcohol': False,
#    'colour': '#f11e00',
#    'name': 'chili peppers',
#    'type': ''},
#   '-LBoX7e8fyhKJc63KSAV': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'salt',
#    'type': ''}},
#  {'-LBliqfhELe4RX3pTFr-': {'alcohol': True,
#    'colour': '#e67c1c',
#    'name': 'cognac',
#    'type': 'brandy'},
#   '-LBljS77Ym0FY4LehVBJ': {'alcohol': True,
#    'colour': '#71311b',
#    'id': '-LBljS77Ym0FY4LehVBJ',
#    'name': 'créme de cacao (brown)',
#    'type': 'liqueur'},
#   '-LBlkhP9wKtuy1orVdxT': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'fresh cream',
#    'type': ''},
#   '-LBllYcWA01PTDbMSBvs': {'alcohol': True,
#    'colour': '#e30004',
#    'name': 'campari',
#    'type': 'liqueur'},
#   '-LBlm8P2Hk-bWYymCbKL': {'alcohol': True,
#    'colour': '#c53937',
#    'id': '-LBlm8P2Hk-bWYymCbKL',
#    'name': 'red vermouth',
#    'type': 'vermouth'},
#   '-LBlmO7jPMnfUn7Yy3f-': {'alcohol': False,
#    'colour': '#e3feff',
#    'name': 'soda water',
#    'type': ''},
#   '-LBlmefTdqCEevlK-0Uq': {'alcohol': True,
#    'colour': '#efdc02',
#    'name': 'calvados',
#    'type': 'brandy'},
#   '-LBlmqnY9RFUdY45YcFK': {'alcohol': True,
#    'colour': '#e7fff1',
#    'name': 'gin',
#    'type': 'gin'},
#   '-LBln6aI3hpnj0i_VWKZ': {'alcohol': True,
#    'colour': '#fec72c',
#    'name': 'apricot brandy',
#    'type': 'brandy'},
#   '-LBlnWVeckyQ3PPLC0oi': {'alcohol': True,
#    'colour': '#ffeae4',
#    'name': 'maraschino',
#    'type': 'liqueur'},
#   '-LBlnh1lXNV5k9i-x43i': {'alcohol': False,
#    'colour': '#fff953',
#    'name': 'lemon juice',
#    'type': ''},
#   '-LBlo7wuoDpkRu04_n7D': {'alcohol': True,
#    'colour': '#e9ffe8',
#    'name': 'bacardi carta blanca',
#    'type': 'rum'},
#   '-LBloMo60mxlDhsN2T7u': {'alcohol': False,
#    'colour': '#deff62',
#    'name': 'lime juice',
#    'type': ''},
#   '-LBlohE8PfjT13gsjfnP': {'alcohol': False,
#    'colour': '#e24138',
#    'name': 'grenadine',
#    'type': ''},
#   '-LBlotavscrdDTdWjtqk': {'alcohol': True,
#    'colour': '#ffffff',
#    'name': 'white rum',
#    'type': 'rum'},
#   '-LBlpL1XTBpjk7imUQoX': {'alcohol': True,
#    'colour': '#fefff3',
#    'name': 'triple sec',
#    'type': 'liqueur'},
#   '-LBlphvI5dEcJ9WLf3qa': {'alcohol': True,
#    'colour': '#fafff7',
#    'name': 'old tom gin',
#    'type': 'gin'},
#   '-LBlq01CvGh9acY7zzn8': {'alcohol': False,
#    'colour': '#fe9b06',
#    'name': 'orange bitters',
#    'type': ''},
#   '-LBlqHj0RvrgndFL-8Ik': {'alcohol': False,
#    'colour': '#fc214f',
#    'name': 'raspberry syrup',
#    'type': ''},
#   '-LBlqSUWCECfJTx8aTG4': {'alcohol': False,
#    'colour': '#fffeee',
#    'name': 'egg white',
#    'type': ''},
#   '-LBlqjWBSS8Pw__Wj8r1': {'alcohol': False,
#    'colour': '#fffab1',
#    'name': 'simple syrup',
#    'type': ''},
#   '-LBlqxRyTSDbSwXywasY': {'alcohol': False,
#    'colour': '#fedb04',
#    'name': 'peach bitters',
#    'type': ''},
#   '-LBlrSZXBJX-nDsBH2lF': {'alcohol': False,
#    'colour': '#6ece4e',
#    'name': 'mint leafs',
#    'type': ''},
#   '-LBlrgcjKP2FiJHsovPk': {'alcohol': True,
#    'colour': '#e9ffe8',
#    'name': 'dry vermouth',
#    'type': 'vermouth'},
#   '-LBlrtD1SzFKzBxHXKUe': {'alcohol': False,
#    'colour': '#fdffe8',
#    'name': 'sugar syrup',
#    'type': ''},
#   '-LBlsBaAUaNgUdTCGXrS': {'alcohol': True,
#    'colour': '#dc9f17',
#    'name': 'rye whiskey',
#    'type': 'whiskey'},
#   '-LBlt8sSn663yic7LVi4': {'alcohol': False,
#    'colour': '#f86a0c',
#    'name': 'angostura bitters',
#    'type': ''},
#   '-LBltMdgN_sK2SC1HgMh': {'alcohol': False,
#    'colour': '#ffbc00',
#    'name': 'orange juice',
#    'type': ''},
#   '-LBltb4i8ShWBiFkw_WU': {'alcohol': False,
#    'colour': '#ffef83',
#    'name': 'pineapple juice',
#    'type': ''},
#   '-LBltyi_imj_WaMNhhuk': {'alcohol': True,
#    'colour': '#c6ffa1',
#    'id': '-LBltyi_imj_WaMNhhuk',
#    'name': 'absinthe',
#    'type': 'absinthe'},
#   '-LBluKKHS-9_8JT4Ksb9': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'sugar cube',
#    'type': ''},
#   '-LBluV-NUPQIbY9SKa_r': {'alcohol': False,
#    'colour': '#d9fbff',
#    'name': 'water',
#    'type': ''},
#   '-LBluiwgtsO3I5-ges4P': {'alcohol': True,
#    'colour': '#711802',
#    'name': 'dark rum',
#    'type': 'rum'},
#   '-LBlv2x97v5yNlHq4aVB': {'alcohol': True,
#    'colour': '#efb026',
#    'name': 'brandy',
#    'type': 'brandy'},
#   '-LBlvXdlI0wI1N7WxiE2': {'alcohol': True,
#    'colour': '#af0d00',
#    'name': 'red port',
#    'type': 'wine'},
#   '-LBlvf4TQRbv5AD0MuFi': {'alcohol': False,
#    'colour': '#ffdd22',
#    'name': 'egg yolk',
#    'type': ''},
#   '-LBlw9dtpeo0m4topm3-': {'alcohol': True,
#    'colour': '#ea951f',
#    'name': 'drambuie',
#    'type': 'liqueur'},
#   '-LBlwMlJ0z_m_fGrkYLF': {'alcohol': False,
#    'colour': '#ffdf71',
#    'name': 'orange flower water',
#    'type': ''},
#   '-LBlwglejVHXJ8U89nXa': {'alcohol': False,
#    'colour': '#cb810d',
#    'name': 'vanilla extract',
#    'type': ''},
#   '-LBlwr4jKkppvvXa2U58': {'alcohol': False,
#    'colour': '#ff542b',
#    'name': 'peychaud’s bitters',
#    'type': ''},
#   '-LBlx5sVwv5bGTA1o_cD': {'alcohol': True,
#    'colour': '#fbfff8',
#    'name': 'vodka',
#    'type': 'vodka'},
#   '-LBlxRLy3ebdKVWjlnD4': {'alcohol': True,
#    'colour': '#deffe0',
#    'id': '-LBlxRLy3ebdKVWjlnD4',
#    'name': 'crème de menthe (white)',
#    'type': 'liqueur'},
#   '-LBlxpPezAZyUXNg6FU2': {'alcohol': True,
#    'colour': '#cc7123',
#    'name': 'bourbon whiskey',
#    'type': 'whiskey'},
#   '-LBly0bdcw7z45-iZDxc': {'alcohol': True,
#    'colour': '#fffab9',
#    'name': 'prosecco',
#    'type': 'wine'},
#   '-LBlyE8-xQ947DvlpqWB': {'alcohol': False,
#    'colour': '#fe843b',
#    'name': 'peach puree',
#    'type': ''},
#   '-LBlyPUhbwf1SM0UgCBN': {'alcohol': True,
#    'colour': '#59290d',
#    'name': 'coffee liqueur',
#    'type': 'liqueur'},
#   '-LBlyYQ1bIKB3vnukMzr': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'tomato juice',
#    'type': ''},
#   '-LBlyhQNeNaRaI0d4vNZ': {'alcohol': False,
#    'colour': '#96291a',
#    'name': 'worcestershire sauce',
#    'type': ''},
#   '-LBlyrKnv7mGC4XFcGd-': {'alcohol': False,
#    'colour': '#e63c00',
#    'name': 'tabasco',
#    'type': ''},
#   '-LBlz-1qZPqEKF7NYSP8': {'alcohol': False,
#    'colour': '#d5a163',
#    'name': 'celery salt',
#    'type': ''},
#   '-LBlz9FGvtsTOS6S_GQL': {'alcohol': False,
#    'colour': '#341410',
#    'name': 'pepper',
#    'type': ''},
#   '-LBlzhnRyDQ09E6AnnqI': {'alcohol': True,
#    'colour': '#fff09c',
#    'name': 'cachaça',
#    'type': 'rum'},
#   '-LBlzvRbQlXx8Rbr6RRm': {'alcohol': False,
#    'colour': '#32d930',
#    'name': 'lime',
#    'type': ''},
#   '-LBm-36uI_yaZzPA8eJY': {'alcohol': False,
#    'colour': '#ffffff',
#    'id': '-LBm-36uI_yaZzPA8eJY',
#    'name': 'white sugar',
#    'type': ''},
#   '-LBm-JbwEcFS2hw3s4t4': {'alcohol': True,
#    'colour': '#fff7b0',
#    'name': 'champagne',
#    'type': 'champagne'},
#   '-LBm-Vua1Borvfk_jM2o': {'alcohol': True,
#    'colour': '#fff9c5',
#    'name': 'citron vodka',
#    'type': 'vodka'},
#   '-LBm-i6w_YRrZTTqJNBo': {'alcohol': True,
#    'colour': '#dd8527',
#    'name': 'cointreau',
#    'type': 'liqueur'},
#   '-LBm-pnc5IciyMJ1BW9T': {'alcohol': False,
#    'colour': '#f1251f',
#    'name': 'cranberry juice',
#    'type': ''},
#   '-LBm0-bARNXhm8zC9Bxw': {'alcohol': False,
#    'colour': '#622700',
#    'name': 'cola',
#    'type': ''},
#   '-LBm0BVTNo3J4463A7St': {'alcohol': True,
#    'colour': '#d77924',
#    'name': 'amaretto',
#    'type': 'liqueur'},
#   '-LBm0OLSnWGjQVua7kWK': {'alcohol': True,
#    'colour': '#e5a20d',
#    'name': 'scotch',
#    'type': 'whisky'},
#   '-LBm0jIUVfHnS_uh0sFp': {'alcohol': True,
#    'colour': '#ffdf1a',
#    'name': 'galliano',
#    'type': 'liqueur'},
#   '-LBm0y-EiK5YchTvTEMD': {'alcohol': True,
#    'colour': '#fdfbfb',
#    'name': 'crème de cacao (white)',
#    'type': 'liqueur'},
#   '-LBm1Fe-4qO6qBgifrps': {'alcohol': True,
#    'colour': '#4db84a',
#    'name': 'crème de menthe (green)',
#    'type': 'liqueur'},
#   '-LBoQBfJI9EDNZyqOhK4': {'alcohol': False,
#    'colour': '#fd7c5c',
#    'name': 'grapefruit juice',
#    'type': ''},
#   '-LBoQMZDZYhQB9EH4OZU': {'alcohol': False,
#    'colour': '#fff0a2',
#    'name': 'ginger ale',
#    'type': ''},
#   '-LBoQWaUzfU0bLBpOnGL': {'alcohol': True,
#    'colour': '#f6c62b',
#    'name': 'irish whiskey',
#    'type': 'whiskey'},
#   '-LBoQj3tJ3r0otn3j_7a': {'alcohol': False,
#    'colour': '#2b0300',
#    'name': 'hot coffee',
#    'type': ''},
#   '-LBoQvBqDUqCPPvzY9e9': {'alcohol': True,
#    'colour': '#fffeb8',
#    'name': 'dry white wine',
#    'type': 'wine'},
#   '-LBoR8NPrUFBmq7up1Kb': {'alcohol': True,
#    'colour': '#91001f',
#    'name': 'crème de cassis',
#    'type': 'liqueur'},
#   '-LBoRKY8tCrZGIuyQjoc': {'alcohol': False,
#    'colour': '#d49c3d',
#    'name': 'brown sugar',
#    'type': ''},
#   '-LBoRVusUFRdeJzj0Qyv': {'alcohol': True,
#    'colour': '#fffeda',
#    'name': 'tequila',
#    'type': 'tequila'},
#   '-LBoRh5aXtW_tkNL71Hx': {'alcohol': False,
#    'colour': '#f6fdf0',
#    'name': 'gomme syrup',
#    'type': ''},
#   '-LBoRseyk1AIMGq8vP3B': {'alcohol': True,
#    'colour': '#ffd556',
#    'name': 'orange curaćao',
#    'type': 'liqueur'},
#   '-LBoS1KZWpJ79_MoIu8J': {'alcohol': False,
#    'colour': '#fcfff6',
#    'name': 'orgeat syrup',
#    'type': ''},
#   '-LBoSAxdfk0x6ajDCyYy': {'alcohol': False,
#    'colour': '#78e048',
#    'name': 'mint sprigs',
#    'type': ''},
#   '-LBoSHP-fa5f_3zmttfF': {'alcohol': True,
#    'colour': '#fcffe7',
#    'name': 'white cuban rum',
#    'type': 'rum'},
#   '-LBoSSS8W5WAP1c7_12r': {'alcohol': True,
#    'colour': '#e6bd40',
#    'name': 'ginger beer',
#    'type': 'beer'},
#   '-LBoSWaofGE097Tp471d': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'powdered sugar',
#    'type': ''},
#   '-LBoSc1HQN5bXkZgJ_qM': {'alcohol': False,
#    'colour': '#fefffa',
#    'name': 'coconut cream',
#    'type': ''},
#   '-LBoSnar5BERyv4dkH82': {'alcohol': True,
#    'colour': '#fff7ec',
#    'name': 'kirsch',
#    'type': 'brandy'},
#   '-LBoSw-kJm151UKOXSxE': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'strawberry syrup',
#    'type': ''},
#   '-LBoTNWmYGiI0pTBhNcv': {'alcohol': True,
#    'colour': '#ffecc6',
#    'name': 'peach schnapps',
#    'type': 'liqueur'},
#   '-LBoTW1uPrFCtZLoBFmf': {'alcohol': True,
#    'colour': '#ff0038',
#    'name': 'cherry liqueur',
#    'type': 'liqueur'},
#   '-LBoToKenZGHhF5EgIqD': {'alcohol': True,
#    'colour': '#fff1bd',
#    'name': 'DOM Bénédictine',
#    'type': 'liqueur'},
#   '-LBoTyReEeSeWSpkKJxr': {'alcohol': True,
#    'colour': '#eaa600',
#    'name': 'grand marnier',
#    'type': 'liqueur'},
#   '-LBoUAwqAzikZJHOFXs3': {'alcohol': True,
#    'colour': '#ffd48f',
#    'id': '-LBoUAwqAzikZJHOFXs3',
#    'name': 'baileys irish cream',
#    'type': 'liqueur'},
#   '-LBoUPwGUK9alXSNjYss': {'alcohol': True,
#    'colour': '#722d12',
#    'name': 'kahlúa',
#    'type': 'liqueur'},
#   '-LBoUYBIuEnOCqhXFpIg': {'alcohol': True,
#    'colour': '#ffd900',
#    'name': 'gold rum',
#    'type': 'rum'},
#   '-LBoUqkkS4XuobHeIdKy': {'alcohol': True,
#    'colour': '#44006a',
#    'name': 'blackberry liqueur',
#    'type': 'liqueur'},
#   '-LBoUxyX6tCpRfGYAikY': {'alcohol': False,
#    'colour': '#b3c800',
#    'name': 'olive juice',
#    'type': ''},
#   '-LBoV7KImJ2U3rFheJ8I': {'alcohol': True,
#    'colour': '#cf0034',
#    'name': 'raspberry liqueur',
#    'type': 'liqueur'},
#   '-LBoVRBVqtceQHHzesCF': {'alcohol': False,
#    'colour': '#551f00',
#    'name': 'espresso',
#    'type': ''},
#   '-LBoVZbA8Ci7l_OpubiT': {'alcohol': True,
#    'colour': '#dfffc6',
#    'name': 'pisco',
#    'type': 'brandy'},
#   '-LBoVyfXPGz8eq_L3Htd': {'alcohol': True,
#    'colour': '#ff2455',
#    'name': 'aperol',
#    'type': 'liqueur'},
#   '-LBoW4_Fh3HD0zINzW0f': {'alcohol': False,
#    'colour': '#ffde55',
#    'name': 'agave nectar',
#    'type': ''},
#   '-LBoWG5BfrJK788Wos-R': {'alcohol': True,
#    'colour': '#ffeb82',
#    'name': 'lillet blonde',
#    'type': 'wine'},
#   '-LBoWMs1OIiaTI-5OZf0': {'alcohol': False,
#    'colour': '#fcff00',
#    'name': 'lemon twist',
#    'type': ''},
#   '-LBoWRb3rTc6CV6dKXRc': {'alcohol': False,
#    'colour': '#ffe200',
#    'name': 'honey',
#    'type': ''},
#   '-LBoWYhme38XZtPfdxbZ': {'alcohol': False,
#    'colour': '#ffecb2',
#    'name': 'onion',
#    'type': ''},
#   '-LBoWhwyqcbyMWfT3RaN': {'alcohol': False,
#    'colour': '#f11e00',
#    'name': 'chili peppers',
#    'type': ''},
#   '-LBoX7e8fyhKJc63KSAV': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'salt',
#    'type': ''}},
#  {'-LBliqfhELe4RX3pTFr-': {'alcohol': True,
#    'colour': '#e67c1c',
#    'name': 'cognac',
#    'type': 'brandy'},
#   '-LBljS77Ym0FY4LehVBJ': {'alcohol': True,
#    'colour': '#71311b',
#    'id': '-LBljS77Ym0FY4LehVBJ',
#    'name': 'créme de cacao (brown)',
#    'type': 'liqueur'},
#   '-LBlkhP9wKtuy1orVdxT': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'fresh cream',
#    'type': ''},
#   '-LBllYcWA01PTDbMSBvs': {'alcohol': True,
#    'colour': '#e30004',
#    'name': 'campari',
#    'type': 'liqueur'},
#   '-LBlm8P2Hk-bWYymCbKL': {'alcohol': True,
#    'colour': '#c53937',
#    'id': '-LBlm8P2Hk-bWYymCbKL',
#    'name': 'red vermouth',
#    'type': 'vermouth'},
#   '-LBlmO7jPMnfUn7Yy3f-': {'alcohol': False,
#    'colour': '#e3feff',
#    'name': 'soda water',
#    'type': ''},
#   '-LBlmefTdqCEevlK-0Uq': {'alcohol': True,
#    'colour': '#efdc02',
#    'name': 'calvados',
#    'type': 'brandy'},
#   '-LBlmqnY9RFUdY45YcFK': {'alcohol': True,
#    'colour': '#e7fff1',
#    'name': 'gin',
#    'type': 'gin'},
#   '-LBln6aI3hpnj0i_VWKZ': {'alcohol': True,
#    'colour': '#fec72c',
#    'name': 'apricot brandy',
#    'type': 'brandy'},
#   '-LBlnWVeckyQ3PPLC0oi': {'alcohol': True,
#    'colour': '#ffeae4',
#    'name': 'maraschino',
#    'type': 'liqueur'},
#   '-LBlnh1lXNV5k9i-x43i': {'alcohol': False,
#    'colour': '#fff953',
#    'name': 'lemon juice',
#    'type': ''},
#   '-LBlo7wuoDpkRu04_n7D': {'alcohol': True,
#    'colour': '#e9ffe8',
#    'name': 'bacardi carta blanca',
#    'type': 'rum'},
#   '-LBloMo60mxlDhsN2T7u': {'alcohol': False,
#    'colour': '#deff62',
#    'name': 'lime juice',
#    'type': ''},
#   '-LBlohE8PfjT13gsjfnP': {'alcohol': False,
#    'colour': '#e24138',
#    'name': 'grenadine',
#    'type': ''},
#   '-LBlotavscrdDTdWjtqk': {'alcohol': True,
#    'colour': '#ffffff',
#    'name': 'white rum',
#    'type': 'rum'},
#   '-LBlpL1XTBpjk7imUQoX': {'alcohol': True,
#    'colour': '#fefff3',
#    'name': 'triple sec',
#    'type': 'liqueur'},
#   '-LBlphvI5dEcJ9WLf3qa': {'alcohol': True,
#    'colour': '#fafff7',
#    'name': 'old tom gin',
#    'type': 'gin'},
#   '-LBlq01CvGh9acY7zzn8': {'alcohol': False,
#    'colour': '#fe9b06',
#    'name': 'orange bitters',
#    'type': ''},
#   '-LBlqHj0RvrgndFL-8Ik': {'alcohol': False,
#    'colour': '#fc214f',
#    'name': 'raspberry syrup',
#    'type': ''},
#   '-LBlqSUWCECfJTx8aTG4': {'alcohol': False,
#    'colour': '#fffeee',
#    'name': 'egg white',
#    'type': ''},
#   '-LBlqjWBSS8Pw__Wj8r1': {'alcohol': False,
#    'colour': '#fffab1',
#    'name': 'simple syrup',
#    'type': ''},
#   '-LBlqxRyTSDbSwXywasY': {'alcohol': False,
#    'colour': '#fedb04',
#    'name': 'peach bitters',
#    'type': ''},
#   '-LBlrSZXBJX-nDsBH2lF': {'alcohol': False,
#    'colour': '#6ece4e',
#    'name': 'mint leafs',
#    'type': ''},
#   '-LBlrgcjKP2FiJHsovPk': {'alcohol': True,
#    'colour': '#e9ffe8',
#    'name': 'dry vermouth',
#    'type': 'vermouth'},
#   '-LBlrtD1SzFKzBxHXKUe': {'alcohol': False,
#    'colour': '#fdffe8',
#    'name': 'sugar syrup',
#    'type': ''},
#   '-LBlsBaAUaNgUdTCGXrS': {'alcohol': True,
#    'colour': '#dc9f17',
#    'name': 'rye whiskey',
#    'type': 'whiskey'},
#   '-LBlt8sSn663yic7LVi4': {'alcohol': False,
#    'colour': '#f86a0c',
#    'name': 'angostura bitters',
#    'type': ''},
#   '-LBltMdgN_sK2SC1HgMh': {'alcohol': False,
#    'colour': '#ffbc00',
#    'name': 'orange juice',
#    'type': ''},
#   '-LBltb4i8ShWBiFkw_WU': {'alcohol': False,
#    'colour': '#ffef83',
#    'name': 'pineapple juice',
#    'type': ''},
#   '-LBltyi_imj_WaMNhhuk': {'alcohol': True,
#    'colour': '#c6ffa1',
#    'id': '-LBltyi_imj_WaMNhhuk',
#    'name': 'absinthe',
#    'type': 'absinthe'},
#   '-LBluKKHS-9_8JT4Ksb9': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'sugar cube',
#    'type': ''},
#   '-LBluV-NUPQIbY9SKa_r': {'alcohol': False,
#    'colour': '#d9fbff',
#    'name': 'water',
#    'type': ''},
#   '-LBluiwgtsO3I5-ges4P': {'alcohol': True,
#    'colour': '#711802',
#    'name': 'dark rum',
#    'type': 'rum'},
#   '-LBlv2x97v5yNlHq4aVB': {'alcohol': True,
#    'colour': '#efb026',
#    'name': 'brandy',
#    'type': 'brandy'},
#   '-LBlvXdlI0wI1N7WxiE2': {'alcohol': True,
#    'colour': '#af0d00',
#    'name': 'red port',
#    'type': 'wine'},
#   '-LBlvf4TQRbv5AD0MuFi': {'alcohol': False,
#    'colour': '#ffdd22',
#    'name': 'egg yolk',
#    'type': ''},
#   '-LBlw9dtpeo0m4topm3-': {'alcohol': True,
#    'colour': '#ea951f',
#    'name': 'drambuie',
#    'type': 'liqueur'},
#   '-LBlwMlJ0z_m_fGrkYLF': {'alcohol': False,
#    'colour': '#ffdf71',
#    'name': 'orange flower water',
#    'type': ''},
#   '-LBlwglejVHXJ8U89nXa': {'alcohol': False,
#    'colour': '#cb810d',
#    'name': 'vanilla extract',
#    'type': ''},
#   '-LBlwr4jKkppvvXa2U58': {'alcohol': False,
#    'colour': '#ff542b',
#    'name': 'peychaud’s bitters',
#    'type': ''},
#   '-LBlx5sVwv5bGTA1o_cD': {'alcohol': True,
#    'colour': '#fbfff8',
#    'name': 'vodka',
#    'type': 'vodka'},
#   '-LBlxRLy3ebdKVWjlnD4': {'alcohol': True,
#    'colour': '#deffe0',
#    'id': '-LBlxRLy3ebdKVWjlnD4',
#    'name': 'crème de menthe (white)',
#    'type': 'liqueur'},
#   '-LBlxpPezAZyUXNg6FU2': {'alcohol': True,
#    'colour': '#cc7123',
#    'name': 'bourbon whiskey',
#    'type': 'whiskey'},
#   '-LBly0bdcw7z45-iZDxc': {'alcohol': True,
#    'colour': '#fffab9',
#    'name': 'prosecco',
#    'type': 'wine'},
#   '-LBlyE8-xQ947DvlpqWB': {'alcohol': False,
#    'colour': '#fe843b',
#    'name': 'peach puree',
#    'type': ''},
#   '-LBlyPUhbwf1SM0UgCBN': {'alcohol': True,
#    'colour': '#59290d',
#    'name': 'coffee liqueur',
#    'type': 'liqueur'},
#   '-LBlyYQ1bIKB3vnukMzr': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'tomato juice',
#    'type': ''},
#   '-LBlyhQNeNaRaI0d4vNZ': {'alcohol': False,
#    'colour': '#96291a',
#    'name': 'worcestershire sauce',
#    'type': ''},
#   '-LBlyrKnv7mGC4XFcGd-': {'alcohol': False,
#    'colour': '#e63c00',
#    'name': 'tabasco',
#    'type': ''},
#   '-LBlz-1qZPqEKF7NYSP8': {'alcohol': False,
#    'colour': '#d5a163',
#    'name': 'celery salt',
#    'type': ''},
#   '-LBlz9FGvtsTOS6S_GQL': {'alcohol': False,
#    'colour': '#341410',
#    'name': 'pepper',
#    'type': ''},
#   '-LBlzhnRyDQ09E6AnnqI': {'alcohol': True,
#    'colour': '#fff09c',
#    'name': 'cachaça',
#    'type': 'rum'},
#   '-LBlzvRbQlXx8Rbr6RRm': {'alcohol': False,
#    'colour': '#32d930',
#    'name': 'lime',
#    'type': ''},
#   '-LBm-36uI_yaZzPA8eJY': {'alcohol': False,
#    'colour': '#ffffff',
#    'id': '-LBm-36uI_yaZzPA8eJY',
#    'name': 'white sugar',
#    'type': ''},
#   '-LBm-JbwEcFS2hw3s4t4': {'alcohol': True,
#    'colour': '#fff7b0',
#    'name': 'champagne',
#    'type': 'champagne'},
#   '-LBm-Vua1Borvfk_jM2o': {'alcohol': True,
#    'colour': '#fff9c5',
#    'name': 'citron vodka',
#    'type': 'vodka'},
#   '-LBm-i6w_YRrZTTqJNBo': {'alcohol': True,
#    'colour': '#dd8527',
#    'name': 'cointreau',
#    'type': 'liqueur'},
#   '-LBm-pnc5IciyMJ1BW9T': {'alcohol': False,
#    'colour': '#f1251f',
#    'name': 'cranberry juice',
#    'type': ''},
#   '-LBm0-bARNXhm8zC9Bxw': {'alcohol': False,
#    'colour': '#622700',
#    'name': 'cola',
#    'type': ''},
#   '-LBm0BVTNo3J4463A7St': {'alcohol': True,
#    'colour': '#d77924',
#    'name': 'amaretto',
#    'type': 'liqueur'},
#   '-LBm0OLSnWGjQVua7kWK': {'alcohol': True,
#    'colour': '#e5a20d',
#    'name': 'scotch',
#    'type': 'whisky'},
#   '-LBm0jIUVfHnS_uh0sFp': {'alcohol': True,
#    'colour': '#ffdf1a',
#    'name': 'galliano',
#    'type': 'liqueur'},
#   '-LBm0y-EiK5YchTvTEMD': {'alcohol': True,
#    'colour': '#fdfbfb',
#    'name': 'crème de cacao (white)',
#    'type': 'liqueur'},
#   '-LBm1Fe-4qO6qBgifrps': {'alcohol': True,
#    'colour': '#4db84a',
#    'name': 'crème de menthe (green)',
#    'type': 'liqueur'},
#   '-LBoQBfJI9EDNZyqOhK4': {'alcohol': False,
#    'colour': '#fd7c5c',
#    'name': 'grapefruit juice',
#    'type': ''},
#   '-LBoQMZDZYhQB9EH4OZU': {'alcohol': False,
#    'colour': '#fff0a2',
#    'name': 'ginger ale',
#    'type': ''},
#   '-LBoQWaUzfU0bLBpOnGL': {'alcohol': True,
#    'colour': '#f6c62b',
#    'name': 'irish whiskey',
#    'type': 'whiskey'},
#   '-LBoQj3tJ3r0otn3j_7a': {'alcohol': False,
#    'colour': '#2b0300',
#    'name': 'hot coffee',
#    'type': ''},
#   '-LBoQvBqDUqCPPvzY9e9': {'alcohol': True,
#    'colour': '#fffeb8',
#    'name': 'dry white wine',
#    'type': 'wine'},
#   '-LBoR8NPrUFBmq7up1Kb': {'alcohol': True,
#    'colour': '#91001f',
#    'name': 'crème de cassis',
#    'type': 'liqueur'},
#   '-LBoRKY8tCrZGIuyQjoc': {'alcohol': False,
#    'colour': '#d49c3d',
#    'name': 'brown sugar',
#    'type': ''},
#   '-LBoRVusUFRdeJzj0Qyv': {'alcohol': True,
#    'colour': '#fffeda',
#    'name': 'tequila',
#    'type': 'tequila'},
#   '-LBoRh5aXtW_tkNL71Hx': {'alcohol': False,
#    'colour': '#f6fdf0',
#    'name': 'gomme syrup',
#    'type': ''},
#   '-LBoRseyk1AIMGq8vP3B': {'alcohol': True,
#    'colour': '#ffd556',
#    'name': 'orange curaćao',
#    'type': 'liqueur'},
#   '-LBoS1KZWpJ79_MoIu8J': {'alcohol': False,
#    'colour': '#fcfff6',
#    'name': 'orgeat syrup',
#    'type': ''},
#   '-LBoSAxdfk0x6ajDCyYy': {'alcohol': False,
#    'colour': '#78e048',
#    'name': 'mint sprigs',
#    'type': ''},
#   '-LBoSHP-fa5f_3zmttfF': {'alcohol': True,
#    'colour': '#fcffe7',
#    'name': 'white cuban rum',
#    'type': 'rum'},
#   '-LBoSSS8W5WAP1c7_12r': {'alcohol': True,
#    'colour': '#e6bd40',
#    'name': 'ginger beer',
#    'type': 'beer'},
#   '-LBoSWaofGE097Tp471d': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'powdered sugar',
#    'type': ''},
#   '-LBoSc1HQN5bXkZgJ_qM': {'alcohol': False,
#    'colour': '#fefffa',
#    'name': 'coconut cream',
#    'type': ''},
#   '-LBoSnar5BERyv4dkH82': {'alcohol': True,
#    'colour': '#fff7ec',
#    'name': 'kirsch',
#    'type': 'brandy'},
#   '-LBoSw-kJm151UKOXSxE': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'strawberry syrup',
#    'type': ''},
#   '-LBoTNWmYGiI0pTBhNcv': {'alcohol': True,
#    'colour': '#ffecc6',
#    'name': 'peach schnapps',
#    'type': 'liqueur'},
#   '-LBoTW1uPrFCtZLoBFmf': {'alcohol': True,
#    'colour': '#ff0038',
#    'name': 'cherry liqueur',
#    'type': 'liqueur'},
#   '-LBoToKenZGHhF5EgIqD': {'alcohol': True,
#    'colour': '#fff1bd',
#    'name': 'DOM Bénédictine',
#    'type': 'liqueur'},
#   '-LBoTyReEeSeWSpkKJxr': {'alcohol': True,
#    'colour': '#eaa600',
#    'name': 'grand marnier',
#    'type': 'liqueur'},
#   '-LBoUAwqAzikZJHOFXs3': {'alcohol': True,
#    'colour': '#ffd48f',
#    'id': '-LBoUAwqAzikZJHOFXs3',
#    'name': 'baileys irish cream',
#    'type': 'liqueur'},
#   '-LBoUPwGUK9alXSNjYss': {'alcohol': True,
#    'colour': '#722d12',
#    'name': 'kahlúa',
#    'type': 'liqueur'},
#   '-LBoUYBIuEnOCqhXFpIg': {'alcohol': True,
#    'colour': '#ffd900',
#    'name': 'gold rum',
#    'type': 'rum'},
#   '-LBoUqkkS4XuobHeIdKy': {'alcohol': True,
#    'colour': '#44006a',
#    'name': 'blackberry liqueur',
#    'type': 'liqueur'},
#   '-LBoUxyX6tCpRfGYAikY': {'alcohol': False,
#    'colour': '#b3c800',
#    'name': 'olive juice',
#    'type': ''},
#   '-LBoV7KImJ2U3rFheJ8I': {'alcohol': True,
#    'colour': '#cf0034',
#    'name': 'raspberry liqueur',
#    'type': 'liqueur'},
#   '-LBoVRBVqtceQHHzesCF': {'alcohol': False,
#    'colour': '#551f00',
#    'name': 'espresso',
#    'type': ''},
#   '-LBoVZbA8Ci7l_OpubiT': {'alcohol': True,
#    'colour': '#dfffc6',
#    'name': 'pisco',
#    'type': 'brandy'},
#   '-LBoVyfXPGz8eq_L3Htd': {'alcohol': True,
#    'colour': '#ff2455',
#    'name': 'aperol',
#    'type': 'liqueur'},
#   '-LBoW4_Fh3HD0zINzW0f': {'alcohol': False,
#    'colour': '#ffde55',
#    'name': 'agave nectar',
#    'type': ''},
#   '-LBoWG5BfrJK788Wos-R': {'alcohol': True,
#    'colour': '#ffeb82',
#    'name': 'lillet blonde',
#    'type': 'wine'},
#   '-LBoWMs1OIiaTI-5OZf0': {'alcohol': False,
#    'colour': '#fcff00',
#    'name': 'lemon twist',
#    'type': ''},
#   '-LBoWRb3rTc6CV6dKXRc': {'alcohol': False,
#    'colour': '#ffe200',
#    'name': 'honey',
#    'type': ''},
#   '-LBoWYhme38XZtPfdxbZ': {'alcohol': False,
#    'colour': '#ffecb2',
#    'name': 'onion',
#    'type': ''},
#   '-LBoWhwyqcbyMWfT3RaN': {'alcohol': False,
#    'colour': '#f11e00',
#    'name': 'chili peppers',
#    'type': ''},
#   '-LBoX7e8fyhKJc63KSAV': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'salt',
#    'type': ''}},
#  {'-LBliqfhELe4RX3pTFr-': {'alcohol': True,
#    'colour': '#e67c1c',
#    'name': 'cognac',
#    'type': 'brandy'},
#   '-LBljS77Ym0FY4LehVBJ': {'alcohol': True,
#    'colour': '#71311b',
#    'id': '-LBljS77Ym0FY4LehVBJ',
#    'name': 'créme de cacao (brown)',
#    'type': 'liqueur'},
#   '-LBlkhP9wKtuy1orVdxT': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'fresh cream',
#    'type': ''},
#   '-LBllYcWA01PTDbMSBvs': {'alcohol': True,
#    'colour': '#e30004',
#    'name': 'campari',
#    'type': 'liqueur'},
#   '-LBlm8P2Hk-bWYymCbKL': {'alcohol': True,
#    'colour': '#c53937',
#    'id': '-LBlm8P2Hk-bWYymCbKL',
#    'name': 'red vermouth',
#    'type': 'vermouth'},
#   '-LBlmO7jPMnfUn7Yy3f-': {'alcohol': False,
#    'colour': '#e3feff',
# ...
#    'type': ''},
#   '-LBoQWaUzfU0bLBpOnGL': {'alcohol': True,
#    'colour': '#f6c62b',
#    'name': 'irish whiskey',
#    'type': 'whiskey'},
#   '-LBoQj3tJ3r0otn3j_7a': {'alcohol': False,
#    'colour': '#2b0300',
#    'name': 'hot coffee',
#    'type': ''},
#   '-LBoQvBqDUqCPPvzY9e9': {'alcohol': True,
#    'colour': '#fffeb8',
#    'name': 'dry white wine',
#    'type': 'wine'},
#   '-LBoR8NPrUFBmq7up1Kb': {'alcohol': True,
#    'colour': '#91001f',
#    'name': 'crème de cassis',
#    'type': 'liqueur'},
#   '-LBoRKY8tCrZGIuyQjoc': {'alcohol': False,
#    'colour': '#d49c3d',
#    'name': 'brown sugar',
#    'type': ''},
#   '-LBoRVusUFRdeJzj0Qyv': {'alcohol': True,
#    'colour': '#fffeda',
#    'name': 'tequila',
#    'type': 'tequila'},
#   '-LBoRh5aXtW_tkNL71Hx': {'alcohol': False,
#    'colour': '#f6fdf0',
#    'name': 'gomme syrup',
#    'type': ''},
#   '-LBoRseyk1AIMGq8vP3B': {'alcohol': True,
#    'colour': '#ffd556',
#    'name': 'orange curaćao',
#    'type': 'liqueur'},
#   '-LBoS1KZWpJ79_MoIu8J': {'alcohol': False,
#    'colour': '#fcfff6',
#    'name': 'orgeat syrup',
#    'type': ''},
#   '-LBoSAxdfk0x6ajDCyYy': {'alcohol': False,
#    'colour': '#78e048',
#    'name': 'mint sprigs',
#    'type': ''},
#   '-LBoSHP-fa5f_3zmttfF': {'alcohol': True,
#    'colour': '#fcffe7',
#    'name': 'white cuban rum',
#    'type': 'rum'},
#   '-LBoSSS8W5WAP1c7_12r': {'alcohol': True,
#    'colour': '#e6bd40',
#    'name': 'ginger beer',
#    'type': 'beer'},
#   '-LBoSWaofGE097Tp471d': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'powdered sugar',
#    'type': ''},
#   '-LBoSc1HQN5bXkZgJ_qM': {'alcohol': False,
#    'colour': '#fefffa',
#    'name': 'coconut cream',
#    'type': ''},
#   '-LBoSnar5BERyv4dkH82': {'alcohol': True,
#    'colour': '#fff7ec',
#    'name': 'kirsch',
#    'type': 'brandy'},
#   '-LBoSw-kJm151UKOXSxE': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'strawberry syrup',
#    'type': ''},
#   '-LBoTNWmYGiI0pTBhNcv': {'alcohol': True,
#    'colour': '#ffecc6',
#    'name': 'peach schnapps',
#    'type': 'liqueur'},
#   '-LBoTW1uPrFCtZLoBFmf': {'alcohol': True,
#    'colour': '#ff0038',
#    'name': 'cherry liqueur',
#    'type': 'liqueur'},
#   '-LBoToKenZGHhF5EgIqD': {'alcohol': True,
#    'colour': '#fff1bd',
#    'name': 'DOM Bénédictine',
#    'type': 'liqueur'},
#   '-LBoTyReEeSeWSpkKJxr': {'alcohol': True,
#    'colour': '#eaa600',
#    'name': 'grand marnier',
#    'type': 'liqueur'},
#   '-LBoUAwqAzikZJHOFXs3': {'alcohol': True,
#    'colour': '#ffd48f',
#    'id': '-LBoUAwqAzikZJHOFXs3',
#    'name': 'baileys irish cream',
#    'type': 'liqueur'},
#   '-LBoUPwGUK9alXSNjYss': {'alcohol': True,
#    'colour': '#722d12',
#    'name': 'kahlúa',
#    'type': 'liqueur'},
#   '-LBoUYBIuEnOCqhXFpIg': {'alcohol': True,
#    'colour': '#ffd900',
#    'name': 'gold rum',
#    'type': 'rum'},
#   '-LBoUqkkS4XuobHeIdKy': {'alcohol': True,
#    'colour': '#44006a',
#    'name': 'blackberry liqueur',
#    'type': 'liqueur'},
#   '-LBoUxyX6tCpRfGYAikY': {'alcohol': False,
#    'colour': '#b3c800',
#    'name': 'olive juice',
#    'type': ''},
#   '-LBoV7KImJ2U3rFheJ8I': {'alcohol': True,
#    'colour': '#cf0034',
#    'name': 'raspberry liqueur',
#    'type': 'liqueur'},
#   '-LBoVRBVqtceQHHzesCF': {'alcohol': False,
#    'colour': '#551f00',
#    'name': 'espresso',
#    'type': ''},
#   '-LBoVZbA8Ci7l_OpubiT': {'alcohol': True,
#    'colour': '#dfffc6',
#    'name': 'pisco',
#    'type': 'brandy'},
#   '-LBoVyfXPGz8eq_L3Htd': {'alcohol': True,
#    'colour': '#ff2455',
#    'name': 'aperol',
#    'type': 'liqueur'},
#   '-LBoW4_Fh3HD0zINzW0f': {'alcohol': False,
#    'colour': '#ffde55',
#    'name': 'agave nectar',
#    'type': ''},
#   '-LBoWG5BfrJK788Wos-R': {'alcohol': True,
#    'colour': '#ffeb82',
#    'name': 'lillet blonde',
#    'type': 'wine'},
#   '-LBoWMs1OIiaTI-5OZf0': {'alcohol': False,
#    'colour': '#fcff00',
#    'name': 'lemon twist',
#    'type': ''},
#   '-LBoWRb3rTc6CV6dKXRc': {'alcohol': False,
#    'colour': '#ffe200',
#    'name': 'honey',
#    'type': ''},
#   '-LBoWYhme38XZtPfdxbZ': {'alcohol': False,
#    'colour': '#ffecb2',
#    'name': 'onion',
#    'type': ''},
#   '-LBoWhwyqcbyMWfT3RaN': {'alcohol': False,
#    'colour': '#f11e00',
#    'name': 'chili peppers',
#    'type': ''},
#   '-LBoX7e8fyhKJc63KSAV': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'salt',
#    'type': ''}},
#  {'-LBliqfhELe4RX3pTFr-': {'alcohol': True,
#    'colour': '#e67c1c',
#    'name': 'cognac',
#    'type': 'brandy'},
#   '-LBljS77Ym0FY4LehVBJ': {'alcohol': True,
#    'colour': '#71311b',
#    'id': '-LBljS77Ym0FY4LehVBJ',
#    'name': 'créme de cacao (brown)',
#    'type': 'liqueur'},
#   '-LBlkhP9wKtuy1orVdxT': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'fresh cream',
#    'type': ''},
#   '-LBllYcWA01PTDbMSBvs': {'alcohol': True,
#    'colour': '#e30004',
#    'name': 'campari',
#    'type': 'liqueur'},
#   '-LBlm8P2Hk-bWYymCbKL': {'alcohol': True,
#    'colour': '#c53937',
#    'id': '-LBlm8P2Hk-bWYymCbKL',
#    'name': 'red vermouth',
#    'type': 'vermouth'},
#   '-LBlmO7jPMnfUn7Yy3f-': {'alcohol': False,
#    'colour': '#e3feff',
#    'name': 'soda water',
#    'type': ''},
#   '-LBlmefTdqCEevlK-0Uq': {'alcohol': True,
#    'colour': '#efdc02',
#    'name': 'calvados',
#    'type': 'brandy'},
#   '-LBlmqnY9RFUdY45YcFK': {'alcohol': True,
#    'colour': '#e7fff1',
#    'name': 'gin',
#    'type': 'gin'},
#   '-LBln6aI3hpnj0i_VWKZ': {'alcohol': True,
#    'colour': '#fec72c',
#    'name': 'apricot brandy',
#    'type': 'brandy'},
#   '-LBlnWVeckyQ3PPLC0oi': {'alcohol': True,
#    'colour': '#ffeae4',
#    'name': 'maraschino',
#    'type': 'liqueur'},
#   '-LBlnh1lXNV5k9i-x43i': {'alcohol': False,
#    'colour': '#fff953',
#    'name': 'lemon juice',
#    'type': ''},
#   '-LBlo7wuoDpkRu04_n7D': {'alcohol': True,
#    'colour': '#e9ffe8',
#    'name': 'bacardi carta blanca',
#    'type': 'rum'},
#   '-LBloMo60mxlDhsN2T7u': {'alcohol': False,
#    'colour': '#deff62',
#    'name': 'lime juice',
#    'type': ''},
#   '-LBlohE8PfjT13gsjfnP': {'alcohol': False,
#    'colour': '#e24138',
#    'name': 'grenadine',
#    'type': ''},
#   '-LBlotavscrdDTdWjtqk': {'alcohol': True,
#    'colour': '#ffffff',
#    'name': 'white rum',
#    'type': 'rum'},
#   '-LBlpL1XTBpjk7imUQoX': {'alcohol': True,
#    'colour': '#fefff3',
#    'name': 'triple sec',
#    'type': 'liqueur'},
#   '-LBlphvI5dEcJ9WLf3qa': {'alcohol': True,
#    'colour': '#fafff7',
#    'name': 'old tom gin',
#    'type': 'gin'},
#   '-LBlq01CvGh9acY7zzn8': {'alcohol': False,
#    'colour': '#fe9b06',
#    'name': 'orange bitters',
#    'type': ''},
#   '-LBlqHj0RvrgndFL-8Ik': {'alcohol': False,
#    'colour': '#fc214f',
#    'name': 'raspberry syrup',
#    'type': ''},
#   '-LBlqSUWCECfJTx8aTG4': {'alcohol': False,
#    'colour': '#fffeee',
#    'name': 'egg white',
#    'type': ''},
#   '-LBlqjWBSS8Pw__Wj8r1': {'alcohol': False,
#    'colour': '#fffab1',
#    'name': 'simple syrup',
#    'type': ''},
#   '-LBlqxRyTSDbSwXywasY': {'alcohol': False,
#    'colour': '#fedb04',
#    'name': 'peach bitters',
#    'type': ''},
#   '-LBlrSZXBJX-nDsBH2lF': {'alcohol': False,
#    'colour': '#6ece4e',
#    'name': 'mint leafs',
#    'type': ''},
#   '-LBlrgcjKP2FiJHsovPk': {'alcohol': True,
#    'colour': '#e9ffe8',
#    'name': 'dry vermouth',
#    'type': 'vermouth'},
#   '-LBlrtD1SzFKzBxHXKUe': {'alcohol': False,
#    'colour': '#fdffe8',
#    'name': 'sugar syrup',
#    'type': ''},
#   '-LBlsBaAUaNgUdTCGXrS': {'alcohol': True,
#    'colour': '#dc9f17',
#    'name': 'rye whiskey',
#    'type': 'whiskey'},
#   '-LBlt8sSn663yic7LVi4': {'alcohol': False,
#    'colour': '#f86a0c',
#    'name': 'angostura bitters',
#    'type': ''},
#   '-LBltMdgN_sK2SC1HgMh': {'alcohol': False,
#    'colour': '#ffbc00',
#    'name': 'orange juice',
#    'type': ''},
#   '-LBltb4i8ShWBiFkw_WU': {'alcohol': False,
#    'colour': '#ffef83',
#    'name': 'pineapple juice',
#    'type': ''},
#   '-LBltyi_imj_WaMNhhuk': {'alcohol': True,
#    'colour': '#c6ffa1',
#    'id': '-LBltyi_imj_WaMNhhuk',
#    'name': 'absinthe',
#    'type': 'absinthe'},
#   '-LBluKKHS-9_8JT4Ksb9': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'sugar cube',
#    'type': ''},
#   '-LBluV-NUPQIbY9SKa_r': {'alcohol': False,
#    'colour': '#d9fbff',
#    'name': 'water',
#    'type': ''},
#   '-LBluiwgtsO3I5-ges4P': {'alcohol': True,
#    'colour': '#711802',
#    'name': 'dark rum',
#    'type': 'rum'},
#   '-LBlv2x97v5yNlHq4aVB': {'alcohol': True,
#    'colour': '#efb026',
#    'name': 'brandy',
#    'type': 'brandy'},
#   '-LBlvXdlI0wI1N7WxiE2': {'alcohol': True,
#    'colour': '#af0d00',
#    'name': 'red port',
#    'type': 'wine'},
#   '-LBlvf4TQRbv5AD0MuFi': {'alcohol': False,
#    'colour': '#ffdd22',
#    'name': 'egg yolk',
#    'type': ''},
#   '-LBlw9dtpeo0m4topm3-': {'alcohol': True,
#    'colour': '#ea951f',
#    'name': 'drambuie',
#    'type': 'liqueur'},
#   '-LBlwMlJ0z_m_fGrkYLF': {'alcohol': False,
#    'colour': '#ffdf71',
#    'name': 'orange flower water',
#    'type': ''},
#   '-LBlwglejVHXJ8U89nXa': {'alcohol': False,
#    'colour': '#cb810d',
#    'name': 'vanilla extract',
#    'type': ''},
#   '-LBlwr4jKkppvvXa2U58': {'alcohol': False,
#    'colour': '#ff542b',
#    'name': 'peychaud’s bitters',
#    'type': ''},
#   '-LBlx5sVwv5bGTA1o_cD': {'alcohol': True,
#    'colour': '#fbfff8',
#    'name': 'vodka',
#    'type': 'vodka'},
#   '-LBlxRLy3ebdKVWjlnD4': {'alcohol': True,
#    'colour': '#deffe0',
#    'id': '-LBlxRLy3ebdKVWjlnD4',
#    'name': 'crème de menthe (white)',
#    'type': 'liqueur'},
#   '-LBlxpPezAZyUXNg6FU2': {'alcohol': True,
#    'colour': '#cc7123',
#    'name': 'bourbon whiskey',
#    'type': 'whiskey'},
#   '-LBly0bdcw7z45-iZDxc': {'alcohol': True,
#    'colour': '#fffab9',
#    'name': 'prosecco',
#    'type': 'wine'},
#   '-LBlyE8-xQ947DvlpqWB': {'alcohol': False,
#    'colour': '#fe843b',
#    'name': 'peach puree',
#    'type': ''},
#   '-LBlyPUhbwf1SM0UgCBN': {'alcohol': True,
#    'colour': '#59290d',
#    'name': 'coffee liqueur',
#    'type': 'liqueur'},
#   '-LBlyYQ1bIKB3vnukMzr': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'tomato juice',
#    'type': ''},
#   '-LBlyhQNeNaRaI0d4vNZ': {'alcohol': False,
#    'colour': '#96291a',
#    'name': 'worcestershire sauce',
#    'type': ''},
#   '-LBlyrKnv7mGC4XFcGd-': {'alcohol': False,
#    'colour': '#e63c00',
#    'name': 'tabasco',
#    'type': ''},
#   '-LBlz-1qZPqEKF7NYSP8': {'alcohol': False,
#    'colour': '#d5a163',
#    'name': 'celery salt',
#    'type': ''},
#   '-LBlz9FGvtsTOS6S_GQL': {'alcohol': False,
#    'colour': '#341410',
#    'name': 'pepper',
#    'type': ''},
#   '-LBlzhnRyDQ09E6AnnqI': {'alcohol': True,
#    'colour': '#fff09c',
#    'name': 'cachaça',
#    'type': 'rum'},
#   '-LBlzvRbQlXx8Rbr6RRm': {'alcohol': False,
#    'colour': '#32d930',
#    'name': 'lime',
#    'type': ''},
#   '-LBm-36uI_yaZzPA8eJY': {'alcohol': False,
#    'colour': '#ffffff',
#    'id': '-LBm-36uI_yaZzPA8eJY',
#    'name': 'white sugar',
#    'type': ''},
#   '-LBm-JbwEcFS2hw3s4t4': {'alcohol': True,
#    'colour': '#fff7b0',
#    'name': 'champagne',
#    'type': 'champagne'},
#   '-LBm-Vua1Borvfk_jM2o': {'alcohol': True,
#    'colour': '#fff9c5',
#    'name': 'citron vodka',
#    'type': 'vodka'},
#   '-LBm-i6w_YRrZTTqJNBo': {'alcohol': True,
#    'colour': '#dd8527',
#    'name': 'cointreau',
#    'type': 'liqueur'},
#   '-LBm-pnc5IciyMJ1BW9T': {'alcohol': False,
#    'colour': '#f1251f',
#    'name': 'cranberry juice',
#    'type': ''},
#   '-LBm0-bARNXhm8zC9Bxw': {'alcohol': False,
#    'colour': '#622700',
#    'name': 'cola',
#    'type': ''},
#   '-LBm0BVTNo3J4463A7St': {'alcohol': True,
#    'colour': '#d77924',
#    'name': 'amaretto',
#    'type': 'liqueur'},
#   '-LBm0OLSnWGjQVua7kWK': {'alcohol': True,
#    'colour': '#e5a20d',
#    'name': 'scotch',
#    'type': 'whisky'},
#   '-LBm0jIUVfHnS_uh0sFp': {'alcohol': True,
#    'colour': '#ffdf1a',
#    'name': 'galliano',
#    'type': 'liqueur'},
#   '-LBm0y-EiK5YchTvTEMD': {'alcohol': True,
#    'colour': '#fdfbfb',
#    'name': 'crème de cacao (white)',
#    'type': 'liqueur'},
#   '-LBm1Fe-4qO6qBgifrps': {'alcohol': True,
#    'colour': '#4db84a',
#    'name': 'crème de menthe (green)',
#    'type': 'liqueur'},
#   '-LBoQBfJI9EDNZyqOhK4': {'alcohol': False,
#    'colour': '#fd7c5c',
#    'name': 'grapefruit juice',
#    'type': ''},
#   '-LBoQMZDZYhQB9EH4OZU': {'alcohol': False,
#    'colour': '#fff0a2',
#    'name': 'ginger ale',
#    'type': ''},
#   '-LBoQWaUzfU0bLBpOnGL': {'alcohol': True,
#    'colour': '#f6c62b',
#    'name': 'irish whiskey',
#    'type': 'whiskey'},
#   '-LBoQj3tJ3r0otn3j_7a': {'alcohol': False,
#    'colour': '#2b0300',
#    'name': 'hot coffee',
#    'type': ''},
#   '-LBoQvBqDUqCPPvzY9e9': {'alcohol': True,
#    'colour': '#fffeb8',
#    'name': 'dry white wine',
#    'type': 'wine'},
#   '-LBoR8NPrUFBmq7up1Kb': {'alcohol': True,
#    'colour': '#91001f',
#    'name': 'crème de cassis',
#    'type': 'liqueur'},
#   '-LBoRKY8tCrZGIuyQjoc': {'alcohol': False,
#    'colour': '#d49c3d',
#    'name': 'brown sugar',
#    'type': ''},
#   '-LBoRVusUFRdeJzj0Qyv': {'alcohol': True,
#    'colour': '#fffeda',
#    'name': 'tequila',
#    'type': 'tequila'},
#   '-LBoRh5aXtW_tkNL71Hx': {'alcohol': False,
#    'colour': '#f6fdf0',
#    'name': 'gomme syrup',
#    'type': ''},
#   '-LBoRseyk1AIMGq8vP3B': {'alcohol': True,
#    'colour': '#ffd556',
#    'name': 'orange curaćao',
#    'type': 'liqueur'},
#   '-LBoS1KZWpJ79_MoIu8J': {'alcohol': False,
#    'colour': '#fcfff6',
#    'name': 'orgeat syrup',
#    'type': ''},
#   '-LBoSAxdfk0x6ajDCyYy': {'alcohol': False,
#    'colour': '#78e048',
#    'name': 'mint sprigs',
#    'type': ''},
#   '-LBoSHP-fa5f_3zmttfF': {'alcohol': True,
#    'colour': '#fcffe7',
#    'name': 'white cuban rum',
#    'type': 'rum'},
#   '-LBoSSS8W5WAP1c7_12r': {'alcohol': True,
#    'colour': '#e6bd40',
#    'name': 'ginger beer',
#    'type': 'beer'},
#   '-LBoSWaofGE097Tp471d': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'powdered sugar',
#    'type': ''},
#   '-LBoSc1HQN5bXkZgJ_qM': {'alcohol': False,
#    'colour': '#fefffa',
#    'name': 'coconut cream',
#    'type': ''},
#   '-LBoSnar5BERyv4dkH82': {'alcohol': True,
#    'colour': '#fff7ec',
#    'name': 'kirsch',
#    'type': 'brandy'},
#   '-LBoSw-kJm151UKOXSxE': {'alcohol': False,
#    'colour': '#ff3b00',
#    'name': 'strawberry syrup',
#    'type': ''},
#   '-LBoTNWmYGiI0pTBhNcv': {'alcohol': True,
#    'colour': '#ffecc6',
#    'name': 'peach schnapps',
#    'type': 'liqueur'},
#   '-LBoTW1uPrFCtZLoBFmf': {'alcohol': True,
#    'colour': '#ff0038',
#    'name': 'cherry liqueur',
#    'type': 'liqueur'},
#   '-LBoToKenZGHhF5EgIqD': {'alcohol': True,
#    'colour': '#fff1bd',
#    'name': 'DOM Bénédictine',
#    'type': 'liqueur'},
#   '-LBoTyReEeSeWSpkKJxr': {'alcohol': True,
#    'colour': '#eaa600',
#    'name': 'grand marnier',
#    'type': 'liqueur'},
#   '-LBoUAwqAzikZJHOFXs3': {'alcohol': True,
#    'colour': '#ffd48f',
#    'id': '-LBoUAwqAzikZJHOFXs3',
#    'name': 'baileys irish cream',
#    'type': 'liqueur'},
#   '-LBoUPwGUK9alXSNjYss': {'alcohol': True,
#    'colour': '#722d12',
#    'name': 'kahlúa',
#    'type': 'liqueur'},
#   '-LBoUYBIuEnOCqhXFpIg': {'alcohol': True,
#    'colour': '#ffd900',
#    'name': 'gold rum',
#    'type': 'rum'},
#   '-LBoUqkkS4XuobHeIdKy': {'alcohol': True,
#    'colour': '#44006a',
#    'name': 'blackberry liqueur',
#    'type': 'liqueur'},
#   '-LBoUxyX6tCpRfGYAikY': {'alcohol': False,
#    'colour': '#b3c800',
#    'name': 'olive juice',
#    'type': ''},
#   '-LBoV7KImJ2U3rFheJ8I': {'alcohol': True,
#    'colour': '#cf0034',
#    'name': 'raspberry liqueur',
#    'type': 'liqueur'},
#   '-LBoVRBVqtceQHHzesCF': {'alcohol': False,
#    'colour': '#551f00',
#    'name': 'espresso',
#    'type': ''},
#   '-LBoVZbA8Ci7l_OpubiT': {'alcohol': True,
#    'colour': '#dfffc6',
#    'name': 'pisco',
#    'type': 'brandy'},
#   '-LBoVyfXPGz8eq_L3Htd': {'alcohol': True,
#    'colour': '#ff2455',
#    'name': 'aperol',
#    'type': 'liqueur'},
#   '-LBoW4_Fh3HD0zINzW0f': {'alcohol': False,
#    'colour': '#ffde55',
#    'name': 'agave nectar',
#    'type': ''},
#   '-LBoWG5BfrJK788Wos-R': {'alcohol': True,
#    'colour': '#ffeb82',
#    'name': 'lillet blonde',
#    'type': 'wine'},
#   '-LBoWMs1OIiaTI-5OZf0': {'alcohol': False,
#    'colour': '#fcff00',
#    'name': 'lemon twist',
#    'type': ''},
#   '-LBoWRb3rTc6CV6dKXRc': {'alcohol': False,
#    'colour': '#ffe200',
#    'name': 'honey',
#    'type': ''},
#   '-LBoWYhme38XZtPfdxbZ': {'alcohol': False,
#    'colour': '#ffecb2',
#    'name': 'onion',
#    'type': ''},
#   '-LBoWhwyqcbyMWfT3RaN': {'alcohol': False,
#    'colour': '#f11e00',
#    'name': 'chili peppers',
#    'type': ''},
#   '-LBoX7e8fyhKJc63KSAV': {'alcohol': False,
#    'colour': '#ffffff',
#    'name': 'salt',
#    'type': ''}}]

# %%
df = pd.DataFrame.from_records(name)

# %%
df.head()
# Out:
#                                 -LBliqfhELe4RX3pTFr-  \
# 0  {'alcohol': True, 'colour': '#e67c1c', 'name':...
# 1  {'alcohol': True, 'colour': '#e67c1c', 'name':...
# 2  {'alcohol': True, 'colour': '#e67c1c', 'name':...
# 3  {'alcohol': True, 'colour': '#e67c1c', 'name':...
# 4  {'alcohol': True, 'colour': '#e67c1c', 'name':...
#
#                                 -LBljS77Ym0FY4LehVBJ  \
# 0  {'alcohol': True, 'colour': '#71311b', 'id': '...
# 1  {'alcohol': True, 'colour': '#71311b', 'id': '...
# 2  {'alcohol': True, 'colour': '#71311b', 'id': '...
# 3  {'alcohol': True, 'colour': '#71311b', 'id': '...
# 4  {'alcohol': True, 'colour': '#71311b', 'id': '...
#
#                                 -LBlkhP9wKtuy1orVdxT  \
# 0  {'alcohol': False, 'colour': '#ffffff', 'name'...
# 1  {'alcohol': False, 'colour': '#ffffff', 'name'...
# 2  {'alcohol': False, 'colour': '#ffffff', 'name'...
# 3  {'alcohol': False, 'colour': '#ffffff', 'name'...
# 4  {'alcohol': False, 'colour': '#ffffff', 'name'...
#
#                                 -LBllYcWA01PTDbMSBvs  \
# 0  {'alcohol': True, 'colour': '#e30004', 'name':...
# 1  {'alcohol': True, 'colour': '#e30004', 'name':...
# 2  {'alcohol': True, 'colour': '#e30004', 'name':...
# 3  {'alcohol': True, 'colour': '#e30004', 'name':...
# 4  {'alcohol': True, 'colour': '#e30004', 'name':...
#
#                                 -LBlm8P2Hk-bWYymCbKL  \
# 0  {'alcohol': True, 'colour': '#c53937', 'id': '...
# 1  {'alcohol': True, 'colour': '#c53937', 'id': '...
# 2  {'alcohol': True, 'colour': '#c53937', 'id': '...
# 3  {'alcohol': True, 'colour': '#c53937', 'id': '...
# 4  {'alcohol': True, 'colour': '#c53937', 'id': '...
#
#                                 -LBlmO7jPMnfUn7Yy3f-  \
# 0  {'alcohol': False, 'colour': '#e3feff', 'name'...
# 1  {'alcohol': False, 'colour': '#e3feff', 'name'...
# 2  {'alcohol': False, 'colour': '#e3feff', 'name'...
# 3  {'alcohol': False, 'colour': '#e3feff', 'name'...
# 4  {'alcohol': False, 'colour': '#e3feff', 'name'...
#
#                                 -LBlmefTdqCEevlK-0Uq  \
# 0  {'alcohol': True, 'colour': '#efdc02', 'name':...
# 1  {'alcohol': True, 'colour': '#efdc02', 'name':...
# 2  {'alcohol': True, 'colour': '#efdc02', 'name':...
# 3  {'alcohol': True, 'colour': '#efdc02', 'name':...
# 4  {'alcohol': True, 'colour': '#efdc02', 'name':...
#
#                                 -LBlmqnY9RFUdY45YcFK  \
# 0  {'alcohol': True, 'colour': '#e7fff1', 'name':...
# 1  {'alcohol': True, 'colour': '#e7fff1', 'name':...
# 2  {'alcohol': True, 'colour': '#e7fff1', 'name':...
# 3  {'alcohol': True, 'colour': '#e7fff1', 'name':...
# 4  {'alcohol': True, 'colour': '#e7fff1', 'name':...
#
#                                 -LBln6aI3hpnj0i_VWKZ  \
# 0  {'alcohol': True, 'colour': '#fec72c', 'name':...
# 1  {'alcohol': True, 'colour': '#fec72c', 'name':...
# 2  {'alcohol': True, 'colour': '#fec72c', 'name':...
# 3  {'alcohol': True, 'colour': '#fec72c', 'name':...
# 4  {'alcohol': True, 'colour': '#fec72c', 'name':...
#
#                                 -LBlnWVeckyQ3PPLC0oi  ...  \
# 0  {'alcohol': True, 'colour': '#ffeae4', 'name':...  ...
# 1  {'alcohol': True, 'colour': '#ffeae4', 'name':...  ...
# 2  {'alcohol': True, 'colour': '#ffeae4', 'name':...  ...
# 3  {'alcohol': True, 'colour': '#ffeae4', 'name':...  ...
# 4  {'alcohol': True, 'colour': '#ffeae4', 'name':...  ...
#
#                                 -LBoVRBVqtceQHHzesCF  \
# 0  {'alcohol': False, 'colour': '#551f00', 'name'...
# 1  {'alcohol': False, 'colour': '#551f00', 'name'...
# 2  {'alcohol': False, 'colour': '#551f00', 'name'...
# 3  {'alcohol': False, 'colour': '#551f00', 'name'...
# 4  {'alcohol': False, 'colour': '#551f00', 'name'...
#
#                                 -LBoVZbA8Ci7l_OpubiT  \
# 0  {'alcohol': True, 'colour': '#dfffc6', 'name':...
# 1  {'alcohol': True, 'colour': '#dfffc6', 'name':...
# 2  {'alcohol': True, 'colour': '#dfffc6', 'name':...
# 3  {'alcohol': True, 'colour': '#dfffc6', 'name':...
# 4  {'alcohol': True, 'colour': '#dfffc6', 'name':...
#
#                                 -LBoVyfXPGz8eq_L3Htd  \
# 0  {'alcohol': True, 'colour': '#ff2455', 'name':...
# 1  {'alcohol': True, 'colour': '#ff2455', 'name':...
# 2  {'alcohol': True, 'colour': '#ff2455', 'name':...
# 3  {'alcohol': True, 'colour': '#ff2455', 'name':...
# 4  {'alcohol': True, 'colour': '#ff2455', 'name':...
#
#                                 -LBoW4_Fh3HD0zINzW0f  \
# 0  {'alcohol': False, 'colour': '#ffde55', 'name'...
# 1  {'alcohol': False, 'colour': '#ffde55', 'name'...
# 2  {'alcohol': False, 'colour': '#ffde55', 'name'...
# 3  {'alcohol': False, 'colour': '#ffde55', 'name'...
# 4  {'alcohol': False, 'colour': '#ffde55', 'name'...
#
#                                 -LBoWG5BfrJK788Wos-R  \
# 0  {'alcohol': True, 'colour': '#ffeb82', 'name':...
# 1  {'alcohol': True, 'colour': '#ffeb82', 'name':...
# 2  {'alcohol': True, 'colour': '#ffeb82', 'name':...
# 3  {'alcohol': True, 'colour': '#ffeb82', 'name':...
# 4  {'alcohol': True, 'colour': '#ffeb82', 'name':...
#
#                                 -LBoWMs1OIiaTI-5OZf0  \
# 0  {'alcohol': False, 'colour': '#fcff00', 'name'...
# 1  {'alcohol': False, 'colour': '#fcff00', 'name'...
# 2  {'alcohol': False, 'colour': '#fcff00', 'name'...
# 3  {'alcohol': False, 'colour': '#fcff00', 'name'...
# 4  {'alcohol': False, 'colour': '#fcff00', 'name'...
#
#                                 -LBoWRb3rTc6CV6dKXRc  \
# 0  {'alcohol': False, 'colour': '#ffe200', 'name'...
# 1  {'alcohol': False, 'colour': '#ffe200', 'name'...
# 2  {'alcohol': False, 'colour': '#ffe200', 'name'...
# 3  {'alcohol': False, 'colour': '#ffe200', 'name'...
# 4  {'alcohol': False, 'colour': '#ffe200', 'name'...
#
#                                 -LBoWYhme38XZtPfdxbZ  \
# 0  {'alcohol': False, 'colour': '#ffecb2', 'name'...
# 1  {'alcohol': False, 'colour': '#ffecb2', 'name'...
# 2  {'alcohol': False, 'colour': '#ffecb2', 'name'...
# 3  {'alcohol': False, 'colour': '#ffecb2', 'name'...
# 4  {'alcohol': False, 'colour': '#ffecb2', 'name'...
#
#                                 -LBoWhwyqcbyMWfT3RaN  \
# 0  {'alcohol': False, 'colour': '#f11e00', 'name'...
# 1  {'alcohol': False, 'colour': '#f11e00', 'name'...
# 2  {'alcohol': False, 'colour': '#f11e00', 'name'...
# 3  {'alcohol': False, 'colour': '#f11e00', 'name'...
# 4  {'alcohol': False, 'colour': '#f11e00', 'name'...
#
#                                 -LBoX7e8fyhKJc63KSAV
# 0  {'alcohol': False, 'colour': '#ffffff', 'name'...
# 1  {'alcohol': False, 'colour': '#ffffff', 'name'...
# 2  {'alcohol': False, 'colour': '#ffffff', 'name'...
# 3  {'alcohol': False, 'colour': '#ffffff', 'name'...
# 4  {'alcohol': False, 'colour': '#ffffff', 'name'...
#
# [5 rows x 102 columns]

# %%
new_list= df.columns

# %%
new_list
# Out:
# Index(['-LBliqfhELe4RX3pTFr-', '-LBljS77Ym0FY4LehVBJ', '-LBlkhP9wKtuy1orVdxT',
#        '-LBllYcWA01PTDbMSBvs', '-LBlm8P2Hk-bWYymCbKL', '-LBlmO7jPMnfUn7Yy3f-',
#        '-LBlmefTdqCEevlK-0Uq', '-LBlmqnY9RFUdY45YcFK', '-LBln6aI3hpnj0i_VWKZ',
#        '-LBlnWVeckyQ3PPLC0oi',
#        ...
#        '-LBoVRBVqtceQHHzesCF', '-LBoVZbA8Ci7l_OpubiT', '-LBoVyfXPGz8eq_L3Htd',
#        '-LBoW4_Fh3HD0zINzW0f', '-LBoWG5BfrJK788Wos-R', '-LBoWMs1OIiaTI-5OZf0',
#        '-LBoWRb3rTc6CV6dKXRc', '-LBoWYhme38XZtPfdxbZ', '-LBoWhwyqcbyMWfT3RaN',
#        '-LBoX7e8fyhKJc63KSAV'],
#       dtype='object', length=102)

# %%
for x in new_list:
    for y in range(len(name)):
               color.append(int[x]['colour'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-fe81764499e3> in <module>
#       1 for x in new_list:
#       2     for y in range(len(name)):
# ----> 3                color.append(int[x]['colour'])
#
# TypeError: 'type' object is not subscriptable

# %%
ingredients = []
for key, items in data['ingredients'].items():
    this_ingredient = {}
    this_ingredient['alcohol'] = items['alcohol']
    this_ingredient['color'] = items['colour']
    this_ingredient['name'] = items['name']
    ingredients.append(this_ingredient)

# %%
ing_df = pd.DataFrame(ingredients)
ing_df.to_csv('ingredients.csv')
ing_df.head()
# Out:
#    alcohol    color                    name
# 0     True  #e67c1c                  cognac
# 1     True  #71311b  créme de cacao (brown)
# 2    False  #ffffff             fresh cream
# 3     True  #e30004                 campari
# 4     True  #c53937            red vermouth
