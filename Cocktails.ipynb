# %%
import csv
import pandas as pd

# %%
csv = "mr-boston-flattened.csv"

# %%
df = pd.read_csv(csv)

# %%
df.head()
# Out:
#                    name               category measurement-1  \
# 0               Gauguin      Cocktail Classics          2 oz
# 1       Fort Lauderdale      Cocktail Classics      1 1/2 oz
# 2             Apple Pie  Cordials and Liqueurs          3 oz
# 3  Cuban Cocktail No. 1      Cocktail Classics        1/2 oz
# 4           Cool Carlos      Cocktail Classics      1 1/2 oz
#
#        ingredient-1 measurement-2          ingredient-2 measurement-3  \
# 0         Light Rum          1 oz   Passion Fruit Syrup          1 oz
# 1         Light Rum        1/2 oz        Sweet Vermouth        1/4 oz
# 2    Apple schnapps          1 oz     Cinnamon schnapps           NaN
# 3   Juice of a Lime        1/2 oz        Powdered Sugar          2 oz
# 4          Dark rum          2 oz       Cranberry Juice          2 oz
#
#        ingredient-3 measurement-4      ingredient-4 measurement-5  \
# 0       Lemon Juice          1 oz        Lime Juice           NaN
# 1   Juice of Orange        1/4 oz   Juice of a Lime           NaN
# 2       Apple slice           NaN               NaN           NaN
# 3         Light Rum           NaN               NaN           NaN
# 4   Pineapple Juice          1 oz    Orange curacao          1 oz
#
#   ingredient-5 measurement-6 ingredient-6  \
# 0          NaN           NaN          NaN
# 1          NaN           NaN          NaN
# 2          NaN           NaN          NaN
# 3          NaN           NaN          NaN
# 4     Sour Mix           NaN          NaN
#
#                                         instructions                glass  \
# 0  Combine ingredients with a cup of crushed ice ...  Old-Fashioned Glass
# 1  Shake with ice and strain into old-fashioned g...  Old-Fashioned Glass
# 2  Pour into ice-filled old-fashioned glass. Garn...  Old-Fashioned Glass
# 3    Shake with ice and  strain into cocktail glass.       Cocktail Glass
# 4  Mix all ingredients except curacao with ice, s...        Collins Glass
#
#          glass-size
# 0     6 to 8 ounces
# 1     6 to 8 ounces
# 2     6 to 8 ounces
# 3  6 or more ounces
# 4   14 to 16 ounces

# %%
df = df.fillna("")

# %%
df.head(12)
# Out:
#                     name               category measurement-1  \
# 0                Gauguin      Cocktail Classics          2 oz
# 1        Fort Lauderdale      Cocktail Classics      1 1/2 oz
# 2              Apple Pie  Cordials and Liqueurs          3 oz
# 3   Cuban Cocktail No. 1      Cocktail Classics        1/2 oz
# 4            Cool Carlos      Cocktail Classics      1 1/2 oz
# 5           John Collins               Whiskies          2 oz
# 6             Cherry Rum      Cocktail Classics      1 1/4 oz
# 7            Casa Blanca      Cocktail Classics          2 oz
# 8    Caribbean Champagne      Cocktail Classics        1/2 oz
# 9            Amber Amour  Cordials and Liqueurs      1 1/2 oz
# 10         The Joe Lewis               Whiskies      1 1/2 oz
# 11      Bacardi Cocktail      Cocktail Classics      1 1/2 oz
#
#         ingredient-1 measurement-2             ingredient-2 measurement-3  \
# 0          Light Rum          1 oz      Passion Fruit Syrup          1 oz
# 1          Light Rum        1/2 oz           Sweet Vermouth        1/4 oz
# 2     Apple schnapps          1 oz        Cinnamon schnapps
# 3    Juice of a Lime        1/2 oz           Powdered Sugar          2 oz
# 4           Dark rum          2 oz          Cranberry Juice          2 oz
# 5    Bourbon whiskey          1 oz        Fresh lemon juice        1/2 oz
# 6          Light Rum      1 1/2 oz   cherry-flavored brandy          1 oz
# 7          Light Rum      1 1/2 oz               Lime Juice      1 1/2 oz
# 8          Light Rum        1/2 oz          Creme de banana
# 9           Amaretto        1/4 oz        Fresh lemon juice        1/4 oz
# 10    Scotch Whiskey          1 oz       Fresh carrot juice        3/4 oz
# 11       Bacardi Rum        1/2 oz          Juice of a Lime        1/2 oz
#
#          ingredient-3 measurement-4        ingredient-4       measurement-5  \
# 0         Lemon Juice          1 oz          Lime Juice
# 1     Juice of Orange        1/4 oz     Juice of a Lime
# 2         Apple slice
# 3           Light Rum
# 4     Pineapple Juice          1 oz      Orange curacao                1 oz
# 5        Simple Syrup          1 oz          Soda water                1 oz
# 6         Light cream
# 7          Triple Sec      1 1/2 oz          Maraschino
# 8   Chilled Champagne
# 9        Simple Syrup                        Soda water   Maraschino cherry
# 10         Tawny port        1/2 oz   Fresh lemon juice                1 oz
# 11          Grenadine
#
#                                    ingredient-5 measurement-6 ingredient-6  \
# 0
# 1
# 2
# 3
# 4                                      Sour Mix
# 5    Orange and lemon wheels, maraschino cherry
# 6
# 7
# 8
# 9
# 10                                 Agave nectar
# 11
#
#                                          instructions                glass  \
# 0   Combine ingredients with a cup of crushed ice ...  Old-Fashioned Glass
# 1   Shake with ice and strain into old-fashioned g...  Old-Fashioned Glass
# 2   Pour into ice-filled old-fashioned glass. Garn...  Old-Fashioned Glass
# 3     Shake with ice and  strain into cocktail glass.       Cocktail Glass
# 4   Mix all ingredients except curacao with ice, s...        Collins Glass
# 5   Shake first three ingredients with ice and str...        Collins Glass
# 6      Shake with ice and strain into cocktail glass.       Cocktail Glass
# 7      Shake with ice and strain into cocktail glass.       Cocktail Glass
# 8   Pour rum and banana liqueur into champagne flu...      Champagne Flute
# 9   Pour amaretto, lemon juice, and syrup into ice...        Collins Glass
# 10  Shake with ice and strain into chilled cocktai...       Cocktail Glass
# 11     Shake with ice and strain into cocktail glass.       Cocktail Glass
#
#           glass-size
# 0      6 to 8 ounces
# 1      6 to 8 ounces
# 2      6 to 8 ounces
# 3   6 or more ounces
# 4    14 to 16 ounces
# 5    14 to 16 ounces
# 6   6 or more ounces
# 7   6 or more ounces
# 8      6 to 8 ounces
# 9    14 to 16 ounces
# 10  6 or more ounces
# 11  6 or more ounces

# %%
for i in range(1, 7):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
drink_names = []
drink_recipes = []
for i in range(len(df)):
    drink = df.iloc[i, :]
    drink_names.append(drink["name"])
    drink_text = drink["name"] + " - "
    drink_text += drink["glass"] +" - "
    for j in range(1, 7):
        if (drink[f"measurement-{j}"] == "" and drink[f"ingredient-{j}"] == ""):
            pass 
        else:
            j_text = drink[f"measurement-{j}"] + drink[f"ingredient-{j}"] + " - "
            drink_text += j_text
    drink_text += drink["instructions"]        
    drink_recipes.append(drink_text)

# %%
text_df = pd.DataFrame({"name": drink_names, "recipe": drink_recipes})
text_df.head(20)
# Out:
#                     name                                             recipe
# 0                Gauguin  Gauguin - Old-Fashioned Glass - 2 oz Light Rum...
# 1        Fort Lauderdale  Fort Lauderdale - Old-Fashioned Glass - 1 1/2 ...
# 2              Apple Pie  Apple Pie - Old-Fashioned Glass - 3 oz Apple s...
# 3   Cuban Cocktail No. 1  Cuban Cocktail No. 1 - Cocktail Glass - 1/2 oz...
# 4            Cool Carlos  Cool Carlos - Collins Glass - 1 1/2 oz Dark ru...
# 5           John Collins  John Collins - Collins Glass - 2 oz Bourbon wh...
# 6             Cherry Rum  Cherry Rum - Cocktail Glass - 1 1/4 oz Light R...
# 7            Casa Blanca  Casa Blanca - Cocktail Glass - 2 oz Light Rum ...
# 8    Caribbean Champagne  Caribbean Champagne - Champagne Flute - 1/2 oz...
# 9            Amber Amour  Amber Amour - Collins Glass - 1 1/2 oz Amarett...
# 10         The Joe Lewis  The Joe Lewis - Cocktail Glass - 1 1/2 oz Scot...
# 11      Bacardi Cocktail  Bacardi Cocktail - Cocktail Glass - 1 1/2 oz B...
# 12       Apple Pie No. 1  Apple Pie No. 1 - Cocktail Glass - 3/4 oz Ligh...
# 13               Yolanda  Yolanda - Cocktail Glass - 1/2 oz Brandy - 1/2...
# 14        Yellow Rattler  Yellow Rattler - Cocktail Glass - 1 oz Gin - 1...
# 15              Why Not?  Why Not? - Cocktail Glass - 1 oz Gin - 1 oz Ap...
# 16      Amaretto Stinger  Amaretto Stinger - Cocktail Glass - 1 1/2 oz A...
# 17         What The Hell  What The Hell - Old-Fashioned Glass - 1 oz Gin...
# 18      Webster Cocktail  Webster Cocktail - Cocktail Glass - 1/2 oz Jui...
# 19   Union Jack Cocktail  Union Jack Cocktail - Cocktail Glass - 3/4 oz ...

# %%
text_df.iloc[1,:]["recipe"]
# Out:
# 'Fort Lauderdale - Old-Fashioned Glass - 1 1/2 oz Light Rum - 1/2 oz Sweet Vermouth - 1/4 oz Juice of Orange - 1/4 oz Juice of a Lime - Shake with ice and strain into old-fashioned glass over ice cubes. Add a slice of orange.'

# %%
with open("cocktails_text.txt", "w") as text_doc:
    for cocktail_data in text_df["recipe"]:
        text_doc.write(cocktail_data + "\n")
