# %%
import csv
import pandas as pd

# %%
csv = "mr-boston-flattened-(clean-end).csv"
df = pd.read_csv(csv)
df.head()
# Out:
#                    name  glass-size (oz)               category measurement-1  \
# 0               Gauguin                6      Cocktail Classics          2 oz
# 1       Fort Lauderdale                6      Cocktail Classics      1 1/2 oz
# 2             Apple Pie                6  Cordials and Liqueurs          3 oz
# 3  Cuban Cocktail No. 1                6      Cocktail Classics          2 oz
# 4           Cool Carlos               14      Cocktail Classics      1 1/2 oz
#
#       ingredient-1 measurement-2          ingredient-2 measurement-3  \
# 0        Light Rum          1 oz   Passion Fruit Syrup          1 oz
# 1        Light Rum        1/2 oz        Sweet Vermouth        1/4 oz
# 2   Apple schnapps          1 oz     Cinnamon schnapps           NaN
# 3        Light Rum        1/2 oz        Powdered Sugar        1/2 oz
# 4         Dark rum          2 oz       Cranberry Juice          2 oz
#
#        ingredient-3 measurement-4     ingredient-4 measurement-5 ingredient-5  \
# ...

# %%
import numpy as np
meas_1 = np.array(df["measurement-1"].unique())

# %%
ing_1 = np.array(df["ingredient-1"].unique())
ing_2 = np.array(df["ingredient-2"].unique())
ing_3 = np.array(df["ingredient-3"].unique())
ing_4 = np.array(df["ingredient-4"].unique())
ing_5 = np.array(df["ingredient-5"].unique())
ing_6 = np.array(df["ingredient-6"].unique())

# %%
ing_list = []
for ing in ing_1:
    ing_list.append(str(ing).lower().strip())
    
for ing in ing_2:
    ing_list.append(str(ing).lower().strip())
    
for ing in ing_3:
    ing_list.append(str(ing).lower().strip())
    
for ing in ing_4:
    ing_list.append(str(ing).lower().strip())
    
for ing in ing_5:
    ing_list.append(str(ing).lower().strip())
    
for ing in ing_6:
    ing_list.append(str(ing).lower().strip())
    
ing_list
# Out:
# ['light rum',
#  'apple schnapps',
#  'dark rum',
#  'bourbon whiskey',
#  'cherry-flavored brandy',
#  'chilled champagne',
#  'amaretto',
#  'scotch whiskey',
#  'bacardi rum',
#  'apple brandy',
#  'brandy',
#  'gin',
#  'apricot flavored brandy',
#  'gin',
#  'sweet vermouth',
#  'lemon juice',
#  'straight rye whiskey',
#  'grenadine',
#  'green chartreuse',
#  'irish whiskey',
#  'dry vermouth',
#  'juice of a lemon',
#  'orange',
#  'absinthe',
#  'juice of a lime',
#  'rye or bourbon whiskey',
#  'light vermouth',
#  'anisette',
#  'kummel',
#  'bourbon or rye whiskey',
#  'tennessee whiskey',
#  'vodka',
#  'grapefruit juice',
#  'fresh rosemary sprig',
#  'powdered sugar',
#  'wide spiral of lemon zest',
#  'lemon-flavored vodka',
#  'lime juice',
#  'blended scotch whiskey',
#  'bitters',
#  'juice of orange',
#  'orange bitters',
#  'blended scotch whiskey',
#  'white whiskey',
#  'dry gin',
#  'forbidden fruit',
#  'applejack',
#  'port',
#  'maraschino',
# ...

# %%
len(ing_list)
# Out:
# 1030

# %%
ing_set = set(ing_list)
len(ing_set)
# Out:
# 544

# %%
df.head()
# Out:
#                    name  glass-size (oz)               category measurement-1  \
# 0               Gauguin                6      Cocktail Classics          2 oz
# 1       Fort Lauderdale                6      Cocktail Classics      1 1/2 oz
# 2             Apple Pie                6  Cordials and Liqueurs          3 oz
# 3  Cuban Cocktail No. 1                6      Cocktail Classics          2 oz
# 4           Cool Carlos               14      Cocktail Classics      1 1/2 oz
#
#       ingredient-1 measurement-2          ingredient-2 measurement-3  \
# 0        Light Rum          1 oz   Passion Fruit Syrup          1 oz
# 1        Light Rum        1/2 oz        Sweet Vermouth        1/4 oz
# 2   Apple schnapps          1 oz     Cinnamon schnapps           NaN
# 3        Light Rum        1/2 oz        Powdered Sugar        1/2 oz
# 4         Dark rum          2 oz       Cranberry Juice          2 oz
#
#        ingredient-3 measurement-4     ingredient-4 measurement-5 ingredient-5  \
# ...

# %%
for col in df:
    col_list = []
    for row in df[col]:
        col_list.append(str(row).strip().lower())
    df[col] = col_list
df.head()
# Out:
#                    name glass-size (oz)               category measurement-1  \
# 0               gauguin               6      cocktail classics          2 oz
# 1       fort lauderdale               6      cocktail classics      1 1/2 oz
# 2             apple pie               6  cordials and liqueurs          3 oz
# 3  cuban cocktail no. 1               6      cocktail classics          2 oz
# 4           cool carlos              14      cocktail classics      1 1/2 oz
#
#      ingredient-1 measurement-2         ingredient-2 measurement-3  \
# 0       light rum          1 oz  passion fruit syrup          1 oz
# 1       light rum        1/2 oz       sweet vermouth        1/4 oz
# 2  apple schnapps          1 oz    cinnamon schnapps           nan
# 3       light rum        1/2 oz       powdered sugar        1/2 oz
# 4        dark rum          2 oz      cranberry juice          2 oz
#
#       ingredient-3 measurement-4    ingredient-4 measurement-5 ingredient-5  \
# ...

# %%
df.to_csv("mr-boston-endClean-lower.csv", index=False)
